# %% [markdown]
# 1. Construcción de 6 modelos diferentes
#
# Dado que estamos trabajando con un TabTransformer VAE, podemos explorar diversas arquitecturas y metodologías para la generación de datos sintéticos:
#
# *TabTransformer VAE (actual) – Modelo base con arquitectura VAE y Transformer.
#
# *GAN (Generative Adversarial Network) – Modelo basado en redes adversarias generativas para comparación.
#
# *VAE tradicional – Un autoencoder variacional sin Transformer para evaluar su desempeño.
#
# *Normalizing Flows – Un modelo generativo basado en transformaciones invertibles.
#
# *Diffusion Models – Un enfoque basado en modelos de difusión como alternativa moderna.
#
# *Random Forest con Bootstrap – Si bien no es generativo, puede ayudar a evaluar la distribución de los datos sintéticos.
#
#
# 2. Comparación de rendimiento y selección de los mejores modelos
#
# En entregas anteriores se hicieron pruebas de algunos modelos como el GAN y de acuerdo a la literatura se fueron descartando, sobre todo por el manejo de los datos categóricos. Aqui algunos motivos:
#
# *GAN: Las GANs suelen funcionar bien en imágenes pero tienen problemas con datos tabulares, especialmente con características categóricas. Además, son notoriamente difíciles de entrenar y propensas al modo colapso (generar datos repetitivos en lugar de diversificados)
#
# *VAE tradicional: No captura dependencias no lineales complejas tan bien como un Transformer. En datos tabulares, puede generar valores no realistas para variables categóricas debido a la parametrización gaussiana
#
# *Normalizing Flows:Estos modelos requieren transformaciones invertibles, lo que no es ideal para datos mixtos (numéricos y categóricos). Además, pueden ser computacionalmente costosos y difíciles de escalar
#
# *Diffusion Models: Aunque los modelos de difusión han tenido éxito en generación de imágenes, su aplicación en datos tabulares aún es experimental. Además, el proceso de generación es lento comparado con alternativas más eficientes
#
# *Random Forest con Bootstrap:No es un modelo generativo real, sino una técnica de remuestreo. No puede generar nuevas combinaciones de datos más allá de lo observado en el conjunto de entrenamiento.
#
# Después de descartar los otros modelos, TabTransformer VAE sigue siendo una opción fuerte por varias razones:
# *Maneja bien datos mixtos (numéricos + categóricos)
#
# *Captura relaciones complejas
#
# *Generaliza mejor y evita overfitting
#
# *Generación eficiente de datos sintéticos
#
#
# 4. Ajuste de hiperparámetros
#
# Hiperparámetros del modelo
# Estos afectan la arquitectura y el aprendizaje del TabTransformer VAE:
#
# a) Estructura del Transformer
#
# embed_dim = 8 → Dimensión de los embeddings para variables categóricas y numéricas.
# num_heads = 2 → Número de cabezas de atención en cada bloque Transformer.
# num_layers = 2 → Cantidad de bloques Transformer en la arquitectura.
# dropout = 0.1 → Probabilidad de dropout para regularización.
#
# b)Espacio Latente (VAE)
#
# latent_dim = 16 → Dimensión del espacio latente donde se representa la distribución de los datos.
#
# c)Decodificador
#
# hidden_dim = 128 → Tamaño de la capa oculta en la red neuronal del decodificador.
#
# Hiperparámetros de entrenamiento
# Estos afectan la forma en que el modelo aprende:
# a)Optimización
#
# lr = 1e-2 → Tasa de aprendizaje del optimizador Adam.
# b)Pérdidas
#
# mse_loss_fn → MSELoss para la reconstrucción de variables numéricas.
# F.cross_entropy → Pérdida para las variables categóricas.
# kl_loss → Regularización KL para el VAE
#
# c)Datos y entrenamiento
#
# batch_size = 64 → Tamaño del batch en cada iteración del entrenamiento.
# num_epochs = 4000 → Número total de épocas de entrenamiento.
# global_step % 100_000 == 0 → Cada 100,000 pasos, se generan datos sintéticos de prueba.

# %%
import os
import csv
import datetime
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler

# ===============================
# 1. Definición del Modelo VAE con Transformer
# ===============================

class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout=0.1):
        super().__init__()
        self.attention = nn.MultiheadAttention(embed_dim, num_heads, dropout=dropout)
        self.norm1 = nn.LayerNorm(embed_dim)
        self.ff = nn.Sequential(
            nn.Linear(embed_dim, embed_dim * 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(embed_dim * 4, embed_dim)
        )
        self.norm2 = nn.LayerNorm(embed_dim)

    def forward(self, x):
        attn_output, _ = self.attention(x, x, x)
        x = self.norm1(x + attn_output)
        ff_output = self.ff(x)
        x = self.norm2(x + ff_output)
        return x

class TabTransformerVAE(nn.Module):
    def __init__(self, num_numerical, cat_cardinalities, embed_dim, num_heads, num_layers, latent_dim, dropout=0.1):
        """
        Parámetros:
          - num_numerical: número de features numéricas.
          - cat_cardinalities: lista con la cantidad de categorías de cada feature categórica.
          - embed_dim: dimensión de los embeddings.
          - num_heads: número de cabezas de atención.
          - num_layers: cantidad de bloques transformer.
          - latent_dim: dimensión del espacio latente.
          - dropout: tasa de dropout.
        """
        super().__init__()
        self.num_numerical = num_numerical
        self.cat_cardinalities = cat_cardinalities
        self.num_categorical = len(cat_cardinalities)

        # Embeddings para variables categóricas
        self.cat_embeds = nn.ModuleList([nn.Embedding(card, embed_dim) for card in cat_cardinalities])
        # Proyección para variables numéricas
        self.num_projection = nn.Linear(num_numerical, embed_dim)
        # Token CLS
        self.cls_token = nn.Parameter(torch.randn(1, 1, embed_dim))

        # Bloques transformer
        self.transformer_layers = nn.ModuleList([
            TransformerBlock(embed_dim, num_heads, dropout) for _ in range(num_layers)
        ])

        # Obtención del vector latente a partir del token CLS
        self.fc_mu = nn.Linear(embed_dim, latent_dim)
        self.fc_logvar = nn.Linear(embed_dim, latent_dim)

        # Decodificador: salida = [num_numerical] + [sum(cat_cardinalities)]
        total_cat_dims = sum(cat_cardinalities)
        decoder_output_dim = num_numerical + total_cat_dims
        hidden_dim = 128
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, decoder_output_dim)
        )

    def encode(self, numerical_data, categorical_data):
        batch_size = numerical_data.size(0)
        num_feat = self.num_projection(numerical_data).unsqueeze(1)
        cat_feats = [embed(categorical_data[:, i]).unsqueeze(1)
                     for i, embed in enumerate(self.cat_embeds)]
        x = torch.cat([num_feat] + cat_feats, dim=1)
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)
        x = torch.cat([cls_tokens, x], dim=1)
        x = x.transpose(0, 1)
        for layer in self.transformer_layers:
            x = layer(x)
        x = x.transpose(0, 1)
        cls_output = x[:, 0, :]
        mu = self.fc_mu(cls_output)
        logvar = self.fc_logvar(cls_output)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        recon = self.decoder(z)
        num_recon = recon[:, :self.num_numerical]
        cat_recon = []
        start = self.num_numerical
        for card in self.cat_cardinalities:
            end = start + card
            cat_recon.append(recon[:, start:end])
            start = end
        return num_recon, cat_recon

    def forward(self, numerical_data, categorical_data):
        mu, logvar = self.encode(numerical_data, categorical_data)
        z = self.reparameterize(mu, logvar)
        num_recon, cat_recon = self.decode(z)
        return num_recon, cat_recon, mu, logvar

# ===============================
# 2. Preparación de los Datos
# ===============================

# Cargamos el CSV
df = pd.read_csv("final.csv")
df = df.drop(columns=["indice"])
# Convertimos algunas columnas a string para categorizarlas
df['estacionamientos'] = df['estacionamientos'].astype(int).astype(str)
df['edad'] = df['edad'].astype(int).astype(str)

# Definir columnas según lo que queremos modelar
numerical_cols = ['area_construida', 'latitud', 'longitud', 'precio_oferta', 'precio_m2']
categorical_cols = ['tipo_propiedad', 'Municipio', 'Colonia', 'cp', 'estacionamientos', 'edad', 'recamaras', 'banos']

# Escalado: creamos un scaler para cada columna numérica
scalers = {}
for col in numerical_cols:
    scaler = StandardScaler()
    df[[col]] = scaler.fit_transform(df[[col]])
    scalers[col] = scaler

# Mostrar cardinalidades de las categóricas
cat_cardinalities = {col: df[col].nunique() for col in categorical_cols}
print("Cardinalidades de variables categóricas:", cat_cardinalities)

# Crear mapeos para las variables categóricas
cat_mapping = {}
reverse_cat_mapping = {}
for col in categorical_cols:
    categories = df[col].astype('category').cat.categories
    mapping = {cat: code for code, cat in enumerate(categories)}
    reverse_mapping = {code: cat for code, cat in enumerate(categories)}
    cat_mapping[col] = mapping
    reverse_cat_mapping[col] = reverse_mapping

class TabularDataset(Dataset):
    def __init__(self, df, numerical_cols, categorical_cols, cat_mapping):
        self.numerical_data = df[numerical_cols].to_numpy(dtype=np.float32)
        self.categorical_data = np.stack([
            df[col].map(cat_mapping[col]).to_numpy(dtype=np.int64)
            for col in categorical_cols
        ], axis=1)

    def __len__(self):
        return len(self.numerical_data)

    def __getitem__(self, idx):
        num = torch.tensor(self.numerical_data[idx])
        cat = torch.tensor(self.categorical_data[idx])
        return num, cat

dataset = TabularDataset(df, numerical_cols, categorical_cols, cat_mapping)
batch_size = 64
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# ===============================
# 3. Entrenamiento y Checkpoints / Logging
# ===============================

embed_dim = 8
num_heads = 2
num_layers = 2
latent_dim = 16
cat_card_list = [cat_cardinalities[col] for col in categorical_cols]

model = TabTransformerVAE(num_numerical=len(numerical_cols),
                          cat_cardinalities=cat_card_list,
                          embed_dim=embed_dim,
                          num_heads=num_heads,
                          num_layers=num_layers,
                          latent_dim=latent_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
mse_loss_fn = nn.MSELoss()

# Parámetros para checkpoints y log
checkpoint_path = "checkpoint.pt"
log_csv_path = "training_log.csv"

# Si existe un checkpoint, cargar estado
start_epoch = 0
global_step = 0
if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    start_epoch = checkpoint["epoch"] + 1
    global_step = checkpoint["global_step"]
    print(f"Cargando checkpoint del epoch {start_epoch}")

# Si no existe el CSV de log, crearlo con header
if not os.path.exists(log_csv_path):
    with open(log_csv_path, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["timestamp", "epoch", "loss_total", "loss_num", "loss_cat", "loss_kl"])

num_epochs = 4000

for epoch in range(start_epoch, num_epochs):
    epoch_loss_total = 0.0
    epoch_loss_num = 0.0
    epoch_loss_cat = 0.0
    epoch_loss_kl = 0.0
    num_batches = 0

    for numerical_batch, categorical_batch in dataloader:
        optimizer.zero_grad()
        num_recon, cat_recon, mu, logvar = model(numerical_batch, categorical_batch)

        loss_num = mse_loss_fn(num_recon, numerical_batch)
        loss_cat = 0.0
        for i in range(len(categorical_cols)):
            loss_cat += F.cross_entropy(cat_recon[i], categorical_batch[:, i])
        kl_loss = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

        loss = loss_num + loss_cat + kl_loss
        loss.backward()
        optimizer.step()

        epoch_loss_total += loss.item()
        epoch_loss_num += loss_num.item()
        epoch_loss_cat += loss_cat.item()
        epoch_loss_kl += kl_loss.item()
        num_batches += 1
        global_step += 1

        if global_step % 100_000 == 0:
            model.eval()
            with torch.no_grad():
                synthetic_batch_size = 5
                z = torch.randn(synthetic_batch_size, latent_dim)
                num_syn, cat_syn_logits = model.decode(z)
                num_syn_np = num_syn.cpu().numpy()

                synthetic_nums = []
                for i, col in enumerate(numerical_cols):
                    col_vals = num_syn_np[:, i].reshape(-1, 1)
                    col_inv = scalers[col].inverse_transform(col_vals).flatten()
                    synthetic_nums.append(col_inv)
                synthetic_nums = np.column_stack(synthetic_nums)

                synthetic_cat = []
                for i, logits in enumerate(cat_syn_logits):
                    preds = torch.argmax(logits, dim=1).cpu().numpy()
                    preds = [reverse_cat_mapping[categorical_cols[i]][p] for p in preds]
                    synthetic_cat.append(preds)
                synthetic_cat = np.column_stack(synthetic_cat)

                synthetic_df = pd.DataFrame(synthetic_nums, columns=numerical_cols)
                for i, col in enumerate(categorical_cols):
                    synthetic_df[col] = synthetic_cat[:, i]

                print(f"\n[Step {global_step}] Ejemplo de datos sintéticos:")
                print(synthetic_df.head())
            model.train()

    avg_loss_total = epoch_loss_total / num_batches
    avg_loss_num = epoch_loss_num / num_batches
    avg_loss_cat = epoch_loss_cat / num_batches
    avg_loss_kl = epoch_loss_kl / num_batches

    print(f"Epoch {epoch+1}/{num_epochs} - Loss Total: {avg_loss_total:.4f} | Num Loss: {avg_loss_num:.4f} | Cat Loss: {avg_loss_cat:.4f} | KL Loss: {avg_loss_kl:.4f}")

    # Guardar log en CSV (agregar una fila)
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(log_csv_path, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([timestamp, epoch+1, avg_loss_total, avg_loss_num, avg_loss_cat, avg_loss_kl])

    # Guardar checkpoint cada época (o cada N epochs)
    checkpoint = {
        "epoch": epoch,
        "global_step": global_step,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict()
    }
    torch.save(checkpoint, checkpoint_path)
# Out:
# Cardinalidades de variables categóricas: {'tipo_propiedad': 2, 'Municipio': 16, 'Colonia': 1222, 'cp': 950, 'estacionamientos': 11, 'edad': 91, 'recamaras': 11, 'banos': 11}
# /var/folders/ns/82j_1hfj7f188gzxpzd27zfh0000gn/T/ipykernel_87252/3490699043.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Cargando checkpoint del epoch 1022
# Epoch 1023/4000 - Loss Total: 2.3559 | Num Loss: 0.2965 | Cat Loss: 0.8442 | KL Loss: 1.2151
# Epoch 1024/4000 - Loss Total: 2.3570 | Num Loss: 0.2949 | Cat Loss: 0.8453 | KL Loss: 1.2168
# Epoch 1025/4000 - Loss Total: 2.3564 | Num Loss: 0.2958 | Cat Loss: 0.8423 | KL Loss: 1.2183
# Epoch 1026/4000 - Loss Total: 2.3489 | Num Loss: 0.2960 | Cat Loss: 0.8361 | KL Loss: 1.2169
# Epoch 1027/4000 - Loss Total: 2.3538 | Num Loss: 0.2952 | Cat Loss: 0.8429 | KL Loss: 1.2157
# Epoch 1028/4000 - Loss Total: 2.3558 | Num Loss: 0.2952 | Cat Loss: 0.8435 | KL Loss: 1.2172
# Epoch 1029/4000 - Loss Total: 2.3540 | Num Loss: 0.2954 | Cat Loss: 0.8417 | KL Loss: 1.2169
# Epoch 1030/4000 - Loss Total: 2.3571 | Num Loss: 0.2952 | Cat Loss: 0.8448 | KL Loss: 1.2172
# Epoch 1031/4000 - Loss Total: 2.3650 | Num Loss: 0.2950 | Cat Loss: 0.8522 | KL Loss: 1.2178
# Epoch 1032/4000 - Loss Total: 2.3533 | Num Loss: 0.2949 | Cat Loss: 0.8409 | KL Loss: 1.2176
# Epoch 1033/4000 - Loss Total: 2.3549 | Num Loss: 0.2945 | Cat Loss: 0.8445 | KL Loss: 1.2159
# Epoch 1034/4000 - Loss Total: 2.3508 | Num Loss: 0.2959 | Cat Loss: 0.8373 | KL Loss: 1.2176
# Epoch 1035/4000 - Loss Total: 2.3564 | Num Loss: 0.2945 | Cat Loss: 0.8434 | KL Loss: 1.2185
# Epoch 1036/4000 - Loss Total: 2.3479 | Num Loss: 0.2948 | Cat Loss: 0.8365 | KL Loss: 1.2166
# Epoch 1037/4000 - Loss Total: 2.3584 | Num Loss: 0.2967 | Cat Loss: 0.8454 | KL Loss: 1.2164
# Epoch 1038/4000 - Loss Total: 2.3533 | Num Loss: 0.2952 | Cat Loss: 0.8411 | KL Loss: 1.2169
# Epoch 1039/4000 - Loss Total: 2.3459 | Num Loss: 0.2953 | Cat Loss: 0.8329 | KL Loss: 1.2177
# Epoch 1040/4000 - Loss Total: 2.3547 | Num Loss: 0.2961 | Cat Loss: 0.8421 | KL Loss: 1.2165
# Epoch 1041/4000 - Loss Total: 2.3601 | Num Loss: 0.2957 | Cat Loss: 0.8467 | KL Loss: 1.2177
# Epoch 1042/4000 - Loss Total: 2.3495 | Num Loss: 0.2960 | Cat Loss: 0.8367 | KL Loss: 1.2167
# Epoch 1043/4000 - Loss Total: 2.3544 | Num Loss: 0.2953 | Cat Loss: 0.8416 | KL Loss: 1.2174
# Epoch 1044/4000 - Loss Total: 2.3520 | Num Loss: 0.2957 | Cat Loss: 0.8390 | KL Loss: 1.2173
# Epoch 1045/4000 - Loss Total: 2.3514 | Num Loss: 0.2959 | Cat Loss: 0.8394 | KL Loss: 1.2161
# Epoch 1046/4000 - Loss Total: 2.3586 | Num Loss: 0.2961 | Cat Loss: 0.8472 | KL Loss: 1.2154
# Epoch 1047/4000 - Loss Total: 2.3513 | Num Loss: 0.2964 | Cat Loss: 0.8378 | KL Loss: 1.2171
# Epoch 1048/4000 - Loss Total: 2.3615 | Num Loss: 0.2952 | Cat Loss: 0.8513 | KL Loss: 1.2150
# Epoch 1049/4000 - Loss Total: 2.3425 | Num Loss: 0.2958 | Cat Loss: 0.8315 | KL Loss: 1.2153
# Epoch 1050/4000 - Loss Total: 2.3571 | Num Loss: 0.2970 | Cat Loss: 0.8439 | KL Loss: 1.2161
# Epoch 1051/4000 - Loss Total: 2.3561 | Num Loss: 0.2961 | Cat Loss: 0.8402 | KL Loss: 1.2199
# Epoch 1052/4000 - Loss Total: 2.3398 | Num Loss: 0.2949 | Cat Loss: 0.8314 | KL Loss: 1.2135
# Epoch 1053/4000 - Loss Total: 2.3531 | Num Loss: 0.2958 | Cat Loss: 0.8408 | KL Loss: 1.2165
# Epoch 1054/4000 - Loss Total: 2.3562 | Num Loss: 0.2961 | Cat Loss: 0.8434 | KL Loss: 1.2168
# Epoch 1055/4000 - Loss Total: 2.3528 | Num Loss: 0.2960 | Cat Loss: 0.8397 | KL Loss: 1.2171
# Epoch 1056/4000 - Loss Total: 2.3576 | Num Loss: 0.2955 | Cat Loss: 0.8448 | KL Loss: 1.2173
# Epoch 1057/4000 - Loss Total: 2.3513 | Num Loss: 0.2960 | Cat Loss: 0.8365 | KL Loss: 1.2188
# Epoch 1058/4000 - Loss Total: 2.3468 | Num Loss: 0.2955 | Cat Loss: 0.8330 | KL Loss: 1.2182
# Epoch 1059/4000 - Loss Total: 2.3694 | Num Loss: 0.2968 | Cat Loss: 0.8542 | KL Loss: 1.2184
# Epoch 1060/4000 - Loss Total: 2.3533 | Num Loss: 0.2968 | Cat Loss: 0.8399 | KL Loss: 1.2166
# Epoch 1061/4000 - Loss Total: 2.3475 | Num Loss: 0.2969 | Cat Loss: 0.8356 | KL Loss: 1.2150
# Epoch 1062/4000 - Loss Total: 2.3527 | Num Loss: 0.2961 | Cat Loss: 0.8376 | KL Loss: 1.2190
# Epoch 1063/4000 - Loss Total: 2.3479 | Num Loss: 0.2947 | Cat Loss: 0.8379 | KL Loss: 1.2153
# Epoch 1064/4000 - Loss Total: 2.3499 | Num Loss: 0.2955 | Cat Loss: 0.8383 | KL Loss: 1.2161
# Epoch 1065/4000 - Loss Total: 2.3524 | Num Loss: 0.2955 | Cat Loss: 0.8399 | KL Loss: 1.2170
# Epoch 1066/4000 - Loss Total: 2.3465 | Num Loss: 0.2963 | Cat Loss: 0.8338 | KL Loss: 1.2164
# Epoch 1067/4000 - Loss Total: 2.3516 | Num Loss: 0.2962 | Cat Loss: 0.8389 | KL Loss: 1.2165
# Epoch 1068/4000 - Loss Total: 2.3485 | Num Loss: 0.2956 | Cat Loss: 0.8341 | KL Loss: 1.2188
#
# [Step 1900000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0        59.836056  19.426294 -99.179649   22010.839844  313.915375
# 1       465.859680  19.431120 -99.181595   99135.781250  231.996017
# 2       106.690552  19.351637 -99.282692   43548.402344  257.033691
# 3       176.092896  19.356544 -99.253525   35699.082031  238.356583
# 4       186.259506  19.338152 -99.218582   44477.429688  259.691986
#
#   tipo_propiedad              Municipio  \
# 0   Departamento             Cuauhtémoc
# 1           Casa         Miguel Hidalgo
# 2   Departamento  Cuajimalpa de Morelos
# 3   Departamento         Álvaro Obregón
# 4   Departamento         Álvaro Obregón
#
#                                        Colonia     cp estacionamientos edad  \
# 0                            Hipodromo Condesa   6170                1   74
# 1                                      Anzures  11590                0    0
# 2                                  Las Tinajas   5348                0    0
# 3                              Lomas De La Era   1860                2   10
# 4  Rancho San Francisco (San Bartolo Ameyalco)   1807                2   15
#
#   recamaras banos
# 0         2     1
# 1         4     4
# 2         2     2
# 3         3     3
# 4         2     3
# Epoch 1069/4000 - Loss Total: 2.3390 | Num Loss: 0.2957 | Cat Loss: 0.8276 | KL Loss: 1.2157
# Epoch 1070/4000 - Loss Total: 2.3468 | Num Loss: 0.2961 | Cat Loss: 0.8362 | KL Loss: 1.2146
# Epoch 1071/4000 - Loss Total: 2.3698 | Num Loss: 0.2961 | Cat Loss: 0.8575 | KL Loss: 1.2163
# Epoch 1072/4000 - Loss Total: 2.3489 | Num Loss: 0.2956 | Cat Loss: 0.8360 | KL Loss: 1.2173
# Epoch 1073/4000 - Loss Total: 2.3406 | Num Loss: 0.2945 | Cat Loss: 0.8307 | KL Loss: 1.2155
# Epoch 1074/4000 - Loss Total: 2.3454 | Num Loss: 0.2950 | Cat Loss: 0.8355 | KL Loss: 1.2149
# Epoch 1075/4000 - Loss Total: 2.3482 | Num Loss: 0.2956 | Cat Loss: 0.8378 | KL Loss: 1.2147
# Epoch 1076/4000 - Loss Total: 2.3465 | Num Loss: 0.2957 | Cat Loss: 0.8343 | KL Loss: 1.2165
# Epoch 1077/4000 - Loss Total: 2.3427 | Num Loss: 0.2964 | Cat Loss: 0.8337 | KL Loss: 1.2126
# Epoch 1078/4000 - Loss Total: 2.3421 | Num Loss: 0.2968 | Cat Loss: 0.8314 | KL Loss: 1.2139
# Epoch 1079/4000 - Loss Total: 2.3472 | Num Loss: 0.2962 | Cat Loss: 0.8361 | KL Loss: 1.2149
# Epoch 1080/4000 - Loss Total: 2.3500 | Num Loss: 0.2953 | Cat Loss: 0.8382 | KL Loss: 1.2166
# Epoch 1081/4000 - Loss Total: 2.3381 | Num Loss: 0.2962 | Cat Loss: 0.8270 | KL Loss: 1.2148
# Epoch 1082/4000 - Loss Total: 2.3449 | Num Loss: 0.2962 | Cat Loss: 0.8304 | KL Loss: 1.2183
# Epoch 1083/4000 - Loss Total: 2.3510 | Num Loss: 0.2958 | Cat Loss: 0.8352 | KL Loss: 1.2200
# Epoch 1084/4000 - Loss Total: 2.3498 | Num Loss: 0.2956 | Cat Loss: 0.8372 | KL Loss: 1.2169
# Epoch 1085/4000 - Loss Total: 2.3546 | Num Loss: 0.2962 | Cat Loss: 0.8390 | KL Loss: 1.2194
# Epoch 1086/4000 - Loss Total: 2.3397 | Num Loss: 0.2970 | Cat Loss: 0.8272 | KL Loss: 1.2155
# Epoch 1087/4000 - Loss Total: 2.3553 | Num Loss: 0.2967 | Cat Loss: 0.8421 | KL Loss: 1.2164
# Epoch 1088/4000 - Loss Total: 2.3403 | Num Loss: 0.2958 | Cat Loss: 0.8289 | KL Loss: 1.2157
# Epoch 1089/4000 - Loss Total: 2.3425 | Num Loss: 0.2950 | Cat Loss: 0.8316 | KL Loss: 1.2159
# Epoch 1090/4000 - Loss Total: 2.3401 | Num Loss: 0.2959 | Cat Loss: 0.8284 | KL Loss: 1.2158
# Epoch 1091/4000 - Loss Total: 2.3506 | Num Loss: 0.2966 | Cat Loss: 0.8369 | KL Loss: 1.2171
# Epoch 1092/4000 - Loss Total: 2.3412 | Num Loss: 0.2953 | Cat Loss: 0.8302 | KL Loss: 1.2156
# Epoch 1093/4000 - Loss Total: 2.3487 | Num Loss: 0.2951 | Cat Loss: 0.8383 | KL Loss: 1.2153
# Epoch 1094/4000 - Loss Total: 2.3424 | Num Loss: 0.2949 | Cat Loss: 0.8313 | KL Loss: 1.2162
# Epoch 1095/4000 - Loss Total: 2.3375 | Num Loss: 0.2961 | Cat Loss: 0.8260 | KL Loss: 1.2155
# Epoch 1096/4000 - Loss Total: 2.3426 | Num Loss: 0.2956 | Cat Loss: 0.8325 | KL Loss: 1.2145
# Epoch 1097/4000 - Loss Total: 2.3478 | Num Loss: 0.2961 | Cat Loss: 0.8363 | KL Loss: 1.2154
# Epoch 1098/4000 - Loss Total: 2.3426 | Num Loss: 0.2960 | Cat Loss: 0.8299 | KL Loss: 1.2167
# Epoch 1099/4000 - Loss Total: 2.3435 | Num Loss: 0.2962 | Cat Loss: 0.8320 | KL Loss: 1.2152
# Epoch 1100/4000 - Loss Total: 2.3534 | Num Loss: 0.2967 | Cat Loss: 0.8415 | KL Loss: 1.2152
# Epoch 1101/4000 - Loss Total: 2.3398 | Num Loss: 0.2964 | Cat Loss: 0.8296 | KL Loss: 1.2139
# Epoch 1102/4000 - Loss Total: 2.3486 | Num Loss: 0.2955 | Cat Loss: 0.8345 | KL Loss: 1.2187
# Epoch 1103/4000 - Loss Total: 2.3480 | Num Loss: 0.2968 | Cat Loss: 0.8365 | KL Loss: 1.2147
# Epoch 1104/4000 - Loss Total: 2.3434 | Num Loss: 0.2953 | Cat Loss: 0.8320 | KL Loss: 1.2161
# Epoch 1105/4000 - Loss Total: 2.3416 | Num Loss: 0.2960 | Cat Loss: 0.8298 | KL Loss: 1.2158
# Epoch 1106/4000 - Loss Total: 2.3435 | Num Loss: 0.2954 | Cat Loss: 0.8341 | KL Loss: 1.2140
# Epoch 1107/4000 - Loss Total: 2.3467 | Num Loss: 0.2953 | Cat Loss: 0.8345 | KL Loss: 1.2169
# Epoch 1108/4000 - Loss Total: 2.3399 | Num Loss: 0.2943 | Cat Loss: 0.8315 | KL Loss: 1.2141
# Epoch 1109/4000 - Loss Total: 2.3401 | Num Loss: 0.2945 | Cat Loss: 0.8306 | KL Loss: 1.2151
# Epoch 1110/4000 - Loss Total: 2.3447 | Num Loss: 0.2955 | Cat Loss: 0.8317 | KL Loss: 1.2175
# Epoch 1111/4000 - Loss Total: 2.3425 | Num Loss: 0.2958 | Cat Loss: 0.8294 | KL Loss: 1.2172
# Epoch 1112/4000 - Loss Total: 2.3542 | Num Loss: 0.2951 | Cat Loss: 0.8406 | KL Loss: 1.2185
# Epoch 1113/4000 - Loss Total: 2.3394 | Num Loss: 0.2950 | Cat Loss: 0.8272 | KL Loss: 1.2171
# Epoch 1114/4000 - Loss Total: 2.3387 | Num Loss: 0.2954 | Cat Loss: 0.8272 | KL Loss: 1.2161
# Epoch 1115/4000 - Loss Total: 2.3376 | Num Loss: 0.2952 | Cat Loss: 0.8264 | KL Loss: 1.2161
# Epoch 1116/4000 - Loss Total: 2.3336 | Num Loss: 0.2956 | Cat Loss: 0.8241 | KL Loss: 1.2139
# Epoch 1117/4000 - Loss Total: 2.3351 | Num Loss: 0.2957 | Cat Loss: 0.8243 | KL Loss: 1.2152
# Epoch 1118/4000 - Loss Total: 2.3439 | Num Loss: 0.2958 | Cat Loss: 0.8304 | KL Loss: 1.2177
# Epoch 1119/4000 - Loss Total: 2.3417 | Num Loss: 0.2958 | Cat Loss: 0.8296 | KL Loss: 1.2162
# Epoch 1120/4000 - Loss Total: 2.3371 | Num Loss: 0.2954 | Cat Loss: 0.8278 | KL Loss: 1.2140
# Epoch 1121/4000 - Loss Total: 2.3436 | Num Loss: 0.2958 | Cat Loss: 0.8317 | KL Loss: 1.2160
# Epoch 1122/4000 - Loss Total: 2.3406 | Num Loss: 0.2957 | Cat Loss: 0.8285 | KL Loss: 1.2164
# Epoch 1123/4000 - Loss Total: 2.3408 | Num Loss: 0.2964 | Cat Loss: 0.8270 | KL Loss: 1.2174
# Epoch 1124/4000 - Loss Total: 2.3408 | Num Loss: 0.2969 | Cat Loss: 0.8276 | KL Loss: 1.2164
#
# [Step 2000000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       233.576584  19.426060 -99.204643   70699.039062  246.930435
# 1       108.412346  19.386688 -99.173897   27478.970703  267.646729
# 2       286.209656  19.438198 -99.200249  103859.546875  355.975677
# 3        45.010372  19.420620 -99.108025   12361.092773  209.515991
# 4       476.248016  19.280180 -99.162270   69237.875000  101.911888
#
#   tipo_propiedad       Municipio           Colonia     cp estacionamientos  \
# 0   Departamento  Miguel Hidalgo           Polanco  11100                0
# 1   Departamento   Benito Juárez  Del Valle Centro   3100                1
# 2   Departamento  Miguel Hidalgo           Granada  11510                1
# 3   Departamento       Iztacalco         Pantitlan   8100                0
# 4           Casa         Tlalpan   Toriello Guerra  14050                0
#
#   edad recamaras banos
# 0    0         3     1
# 1   15         2     2
# 2    0         3     4
# 3    0         1     1
# 4   10         4     4
# Epoch 1125/4000 - Loss Total: 2.3362 | Num Loss: 0.2950 | Cat Loss: 0.8274 | KL Loss: 1.2138
# Epoch 1126/4000 - Loss Total: 2.3424 | Num Loss: 0.2960 | Cat Loss: 0.8317 | KL Loss: 1.2147
# Epoch 1127/4000 - Loss Total: 2.3377 | Num Loss: 0.2962 | Cat Loss: 0.8265 | KL Loss: 1.2149
# Epoch 1128/4000 - Loss Total: 2.3394 | Num Loss: 0.2955 | Cat Loss: 0.8270 | KL Loss: 1.2170
# Epoch 1129/4000 - Loss Total: 2.3409 | Num Loss: 0.2958 | Cat Loss: 0.8304 | KL Loss: 1.2147
# Epoch 1130/4000 - Loss Total: 2.3372 | Num Loss: 0.2956 | Cat Loss: 0.8251 | KL Loss: 1.2165
# Epoch 1131/4000 - Loss Total: 2.3404 | Num Loss: 0.2951 | Cat Loss: 0.8274 | KL Loss: 1.2178
# Epoch 1132/4000 - Loss Total: 2.3357 | Num Loss: 0.2953 | Cat Loss: 0.8247 | KL Loss: 1.2156
# Epoch 1133/4000 - Loss Total: 2.3384 | Num Loss: 0.2962 | Cat Loss: 0.8272 | KL Loss: 1.2151
# Epoch 1134/4000 - Loss Total: 2.3357 | Num Loss: 0.2970 | Cat Loss: 0.8229 | KL Loss: 1.2158
# Epoch 1135/4000 - Loss Total: 2.3318 | Num Loss: 0.2957 | Cat Loss: 0.8223 | KL Loss: 1.2139
# Epoch 1136/4000 - Loss Total: 2.3379 | Num Loss: 0.2958 | Cat Loss: 0.8257 | KL Loss: 1.2163
# Epoch 1137/4000 - Loss Total: 2.3450 | Num Loss: 0.2961 | Cat Loss: 0.8334 | KL Loss: 1.2155
# Epoch 1138/4000 - Loss Total: 2.3355 | Num Loss: 0.2958 | Cat Loss: 0.8229 | KL Loss: 1.2168
# Epoch 1139/4000 - Loss Total: 2.3428 | Num Loss: 0.2951 | Cat Loss: 0.8302 | KL Loss: 1.2174
# Epoch 1140/4000 - Loss Total: 2.3419 | Num Loss: 0.2957 | Cat Loss: 0.8271 | KL Loss: 1.2191
# Epoch 1141/4000 - Loss Total: 2.3515 | Num Loss: 0.2961 | Cat Loss: 0.8410 | KL Loss: 1.2145
# Epoch 1142/4000 - Loss Total: 2.3409 | Num Loss: 0.2964 | Cat Loss: 0.8302 | KL Loss: 1.2143
# Epoch 1143/4000 - Loss Total: 2.3340 | Num Loss: 0.2963 | Cat Loss: 0.8229 | KL Loss: 1.2148
# Epoch 1144/4000 - Loss Total: 2.3385 | Num Loss: 0.2949 | Cat Loss: 0.8297 | KL Loss: 1.2138
# Epoch 1145/4000 - Loss Total: 2.3387 | Num Loss: 0.2960 | Cat Loss: 0.8287 | KL Loss: 1.2141
# Epoch 1146/4000 - Loss Total: 2.3406 | Num Loss: 0.2964 | Cat Loss: 0.8267 | KL Loss: 1.2175
# Epoch 1147/4000 - Loss Total: 2.3345 | Num Loss: 0.2968 | Cat Loss: 0.8230 | KL Loss: 1.2147
# Epoch 1148/4000 - Loss Total: 2.3399 | Num Loss: 0.2953 | Cat Loss: 0.8291 | KL Loss: 1.2156
# Epoch 1149/4000 - Loss Total: 2.3373 | Num Loss: 0.2956 | Cat Loss: 0.8266 | KL Loss: 1.2151
# Epoch 1150/4000 - Loss Total: 2.3347 | Num Loss: 0.2962 | Cat Loss: 0.8231 | KL Loss: 1.2154
# Epoch 1151/4000 - Loss Total: 2.3303 | Num Loss: 0.2951 | Cat Loss: 0.8202 | KL Loss: 1.2149
# Epoch 1152/4000 - Loss Total: 2.3411 | Num Loss: 0.2952 | Cat Loss: 0.8315 | KL Loss: 1.2143
# Epoch 1153/4000 - Loss Total: 2.3322 | Num Loss: 0.2960 | Cat Loss: 0.8211 | KL Loss: 1.2151
# Epoch 1154/4000 - Loss Total: 2.3327 | Num Loss: 0.2948 | Cat Loss: 0.8244 | KL Loss: 1.2134
# Epoch 1155/4000 - Loss Total: 2.3377 | Num Loss: 0.2959 | Cat Loss: 0.8275 | KL Loss: 1.2143
# Epoch 1156/4000 - Loss Total: 2.3427 | Num Loss: 0.2965 | Cat Loss: 0.8298 | KL Loss: 1.2163
# Epoch 1157/4000 - Loss Total: 2.3327 | Num Loss: 0.2957 | Cat Loss: 0.8222 | KL Loss: 1.2148
# Epoch 1158/4000 - Loss Total: 2.3359 | Num Loss: 0.2960 | Cat Loss: 0.8242 | KL Loss: 1.2157
# Epoch 1159/4000 - Loss Total: 2.3460 | Num Loss: 0.2966 | Cat Loss: 0.8336 | KL Loss: 1.2159
# Epoch 1160/4000 - Loss Total: 2.3310 | Num Loss: 0.2961 | Cat Loss: 0.8194 | KL Loss: 1.2155
# Epoch 1161/4000 - Loss Total: 2.3344 | Num Loss: 0.2959 | Cat Loss: 0.8236 | KL Loss: 1.2148
# Epoch 1162/4000 - Loss Total: 2.3385 | Num Loss: 0.2961 | Cat Loss: 0.8269 | KL Loss: 1.2155
# Epoch 1163/4000 - Loss Total: 2.3319 | Num Loss: 0.2957 | Cat Loss: 0.8212 | KL Loss: 1.2150
# Epoch 1164/4000 - Loss Total: 2.3424 | Num Loss: 0.2952 | Cat Loss: 0.8310 | KL Loss: 1.2162
# Epoch 1165/4000 - Loss Total: 2.3291 | Num Loss: 0.2949 | Cat Loss: 0.8202 | KL Loss: 1.2139
# Epoch 1166/4000 - Loss Total: 2.3300 | Num Loss: 0.2945 | Cat Loss: 0.8198 | KL Loss: 1.2157
# Epoch 1167/4000 - Loss Total: 2.3245 | Num Loss: 0.2950 | Cat Loss: 0.8162 | KL Loss: 1.2133
# Epoch 1168/4000 - Loss Total: 2.3417 | Num Loss: 0.2949 | Cat Loss: 0.8302 | KL Loss: 1.2165
# Epoch 1169/4000 - Loss Total: 2.3381 | Num Loss: 0.2947 | Cat Loss: 0.8268 | KL Loss: 1.2166
# Epoch 1170/4000 - Loss Total: 2.3313 | Num Loss: 0.2950 | Cat Loss: 0.8220 | KL Loss: 1.2144
# Epoch 1171/4000 - Loss Total: 2.3341 | Num Loss: 0.2964 | Cat Loss: 0.8227 | KL Loss: 1.2151
# Epoch 1172/4000 - Loss Total: 2.3352 | Num Loss: 0.2948 | Cat Loss: 0.8256 | KL Loss: 1.2148
# Epoch 1173/4000 - Loss Total: 2.3295 | Num Loss: 0.2954 | Cat Loss: 0.8184 | KL Loss: 1.2158
# Epoch 1174/4000 - Loss Total: 2.3285 | Num Loss: 0.2945 | Cat Loss: 0.8195 | KL Loss: 1.2145
# Epoch 1175/4000 - Loss Total: 2.3334 | Num Loss: 0.2946 | Cat Loss: 0.8240 | KL Loss: 1.2148
# Epoch 1176/4000 - Loss Total: 2.3245 | Num Loss: 0.2949 | Cat Loss: 0.8166 | KL Loss: 1.2130
# Epoch 1177/4000 - Loss Total: 2.3348 | Num Loss: 0.2962 | Cat Loss: 0.8222 | KL Loss: 1.2164
# Epoch 1178/4000 - Loss Total: 2.3383 | Num Loss: 0.2956 | Cat Loss: 0.8273 | KL Loss: 1.2154
# Epoch 1179/4000 - Loss Total: 2.3288 | Num Loss: 0.2954 | Cat Loss: 0.8196 | KL Loss: 1.2138
# Epoch 1180/4000 - Loss Total: 2.3301 | Num Loss: 0.2948 | Cat Loss: 0.8195 | KL Loss: 1.2158
#
# [Step 2100000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       144.962143  19.376783 -99.237373   48880.820312  331.263672
# 1       205.280609  19.365191 -99.266716   48309.109375  230.107498
# 2       123.912712  19.414787 -99.178772   42112.339844  374.548004
# 3       211.439072  19.389278 -99.233727   39829.933594  291.193542
# 4        68.487892  19.463078 -99.165466   27719.607422  292.607300
#
#   tipo_propiedad              Municipio                Colonia    cp  \
# 0   Departamento  Cuajimalpa de Morelos                      0  5348
# 1   Departamento  Cuajimalpa de Morelos               El Yaqui  5330
# 2   Departamento             Cuauhtémoc      Hipodromo Condesa  6170
# 3   Departamento         Miguel Hidalgo         Reforma Social  1219
# 4   Departamento             Cuauhtémoc  Santa Maria La Ribera  6400
#
#   estacionamientos edad recamaras banos
# 0                2   15         2     2
# 1                0    5         3     2
# 2                2    9         2     1
# 3                1    3         1     1
# 4                1    3         2     2
# Epoch 1181/4000 - Loss Total: 2.3406 | Num Loss: 0.2949 | Cat Loss: 0.8282 | KL Loss: 1.2174
# Epoch 1182/4000 - Loss Total: 2.3336 | Num Loss: 0.2958 | Cat Loss: 0.8226 | KL Loss: 1.2152
# Epoch 1183/4000 - Loss Total: 2.3300 | Num Loss: 0.2960 | Cat Loss: 0.8171 | KL Loss: 1.2168
# Epoch 1184/4000 - Loss Total: 2.3233 | Num Loss: 0.2952 | Cat Loss: 0.8139 | KL Loss: 1.2142
# Epoch 1185/4000 - Loss Total: 2.3320 | Num Loss: 0.2942 | Cat Loss: 0.8220 | KL Loss: 1.2157
# Epoch 1186/4000 - Loss Total: 2.3395 | Num Loss: 0.2947 | Cat Loss: 0.8272 | KL Loss: 1.2175
# Epoch 1187/4000 - Loss Total: 2.3384 | Num Loss: 0.2949 | Cat Loss: 0.8253 | KL Loss: 1.2182
# Epoch 1188/4000 - Loss Total: 2.3276 | Num Loss: 0.2956 | Cat Loss: 0.8158 | KL Loss: 1.2162
# Epoch 1189/4000 - Loss Total: 2.3487 | Num Loss: 0.2957 | Cat Loss: 0.8373 | KL Loss: 1.2156
# Epoch 1190/4000 - Loss Total: 2.3320 | Num Loss: 0.2962 | Cat Loss: 0.8212 | KL Loss: 1.2146
# Epoch 1191/4000 - Loss Total: 2.3308 | Num Loss: 0.2960 | Cat Loss: 0.8189 | KL Loss: 1.2159
# Epoch 1192/4000 - Loss Total: 2.3218 | Num Loss: 0.2945 | Cat Loss: 0.8132 | KL Loss: 1.2141
# Epoch 1193/4000 - Loss Total: 2.3208 | Num Loss: 0.2947 | Cat Loss: 0.8117 | KL Loss: 1.2144
# Epoch 1194/4000 - Loss Total: 2.3276 | Num Loss: 0.2950 | Cat Loss: 0.8174 | KL Loss: 1.2152
# Epoch 1195/4000 - Loss Total: 2.3322 | Num Loss: 0.2961 | Cat Loss: 0.8212 | KL Loss: 1.2149
# Epoch 1196/4000 - Loss Total: 2.3330 | Num Loss: 0.2947 | Cat Loss: 0.8236 | KL Loss: 1.2147
# Epoch 1197/4000 - Loss Total: 2.3378 | Num Loss: 0.2950 | Cat Loss: 0.8248 | KL Loss: 1.2179
# Epoch 1198/4000 - Loss Total: 2.3323 | Num Loss: 0.2945 | Cat Loss: 0.8212 | KL Loss: 1.2166
# Epoch 1199/4000 - Loss Total: 2.3400 | Num Loss: 0.2955 | Cat Loss: 0.8286 | KL Loss: 1.2159
# Epoch 1200/4000 - Loss Total: 2.3346 | Num Loss: 0.2947 | Cat Loss: 0.8231 | KL Loss: 1.2168
# Epoch 1201/4000 - Loss Total: 2.3275 | Num Loss: 0.2949 | Cat Loss: 0.8165 | KL Loss: 1.2161
# Epoch 1202/4000 - Loss Total: 2.3282 | Num Loss: 0.2962 | Cat Loss: 0.8174 | KL Loss: 1.2146
# Epoch 1203/4000 - Loss Total: 2.3255 | Num Loss: 0.2957 | Cat Loss: 0.8142 | KL Loss: 1.2156
# Epoch 1204/4000 - Loss Total: 2.3258 | Num Loss: 0.2950 | Cat Loss: 0.8163 | KL Loss: 1.2144
# Epoch 1205/4000 - Loss Total: 2.3317 | Num Loss: 0.2947 | Cat Loss: 0.8192 | KL Loss: 1.2178
# Epoch 1206/4000 - Loss Total: 2.3289 | Num Loss: 0.2948 | Cat Loss: 0.8188 | KL Loss: 1.2153
# Epoch 1207/4000 - Loss Total: 2.3258 | Num Loss: 0.2947 | Cat Loss: 0.8140 | KL Loss: 1.2172
# Epoch 1208/4000 - Loss Total: 2.3344 | Num Loss: 0.2964 | Cat Loss: 0.8201 | KL Loss: 1.2180
# Epoch 1209/4000 - Loss Total: 2.3282 | Num Loss: 0.2949 | Cat Loss: 0.8170 | KL Loss: 1.2163
# Epoch 1210/4000 - Loss Total: 2.3193 | Num Loss: 0.2951 | Cat Loss: 0.8084 | KL Loss: 1.2157
# Epoch 1211/4000 - Loss Total: 2.3273 | Num Loss: 0.2962 | Cat Loss: 0.8157 | KL Loss: 1.2154
# Epoch 1212/4000 - Loss Total: 2.3293 | Num Loss: 0.2957 | Cat Loss: 0.8162 | KL Loss: 1.2175
# Epoch 1213/4000 - Loss Total: 2.3286 | Num Loss: 0.2949 | Cat Loss: 0.8186 | KL Loss: 1.2150
# Epoch 1214/4000 - Loss Total: 2.3338 | Num Loss: 0.2954 | Cat Loss: 0.8214 | KL Loss: 1.2170
# Epoch 1215/4000 - Loss Total: 2.3195 | Num Loss: 0.2949 | Cat Loss: 0.8104 | KL Loss: 1.2141
# Epoch 1216/4000 - Loss Total: 2.3369 | Num Loss: 0.2955 | Cat Loss: 0.8268 | KL Loss: 1.2147
# Epoch 1217/4000 - Loss Total: 2.3285 | Num Loss: 0.2957 | Cat Loss: 0.8184 | KL Loss: 1.2144
# Epoch 1218/4000 - Loss Total: 2.3246 | Num Loss: 0.2958 | Cat Loss: 0.8155 | KL Loss: 1.2133
# Epoch 1219/4000 - Loss Total: 2.3298 | Num Loss: 0.2956 | Cat Loss: 0.8168 | KL Loss: 1.2174
# Epoch 1220/4000 - Loss Total: 2.3337 | Num Loss: 0.2960 | Cat Loss: 0.8211 | KL Loss: 1.2166
# Epoch 1221/4000 - Loss Total: 2.3145 | Num Loss: 0.2944 | Cat Loss: 0.8058 | KL Loss: 1.2143
# Epoch 1222/4000 - Loss Total: 2.3352 | Num Loss: 0.2955 | Cat Loss: 0.8240 | KL Loss: 1.2157
# Epoch 1223/4000 - Loss Total: 2.3291 | Num Loss: 0.2957 | Cat Loss: 0.8177 | KL Loss: 1.2158
# Epoch 1224/4000 - Loss Total: 2.3266 | Num Loss: 0.2962 | Cat Loss: 0.8159 | KL Loss: 1.2144
# Epoch 1225/4000 - Loss Total: 2.3202 | Num Loss: 0.2954 | Cat Loss: 0.8098 | KL Loss: 1.2150
# Epoch 1226/4000 - Loss Total: 2.3291 | Num Loss: 0.2951 | Cat Loss: 0.8187 | KL Loss: 1.2154
# Epoch 1227/4000 - Loss Total: 2.3243 | Num Loss: 0.2960 | Cat Loss: 0.8130 | KL Loss: 1.2154
# Epoch 1228/4000 - Loss Total: 2.3278 | Num Loss: 0.2961 | Cat Loss: 0.8161 | KL Loss: 1.2156
# Epoch 1229/4000 - Loss Total: 2.3296 | Num Loss: 0.2951 | Cat Loss: 0.8183 | KL Loss: 1.2161
# Epoch 1230/4000 - Loss Total: 2.3202 | Num Loss: 0.2957 | Cat Loss: 0.8105 | KL Loss: 1.2140
# Epoch 1231/4000 - Loss Total: 2.3288 | Num Loss: 0.2953 | Cat Loss: 0.8169 | KL Loss: 1.2166
# Epoch 1232/4000 - Loss Total: 2.3235 | Num Loss: 0.2949 | Cat Loss: 0.8137 | KL Loss: 1.2150
# Epoch 1233/4000 - Loss Total: 2.3243 | Num Loss: 0.2949 | Cat Loss: 0.8138 | KL Loss: 1.2156
# Epoch 1234/4000 - Loss Total: 2.3232 | Num Loss: 0.2956 | Cat Loss: 0.8141 | KL Loss: 1.2135
# Epoch 1235/4000 - Loss Total: 2.3287 | Num Loss: 0.2955 | Cat Loss: 0.8176 | KL Loss: 1.2156
# Epoch 1236/4000 - Loss Total: 2.3195 | Num Loss: 0.2961 | Cat Loss: 0.8074 | KL Loss: 1.2159
#
# [Step 2200000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       351.909271  19.352091 -99.251671   64765.625000  208.942490
# 1         7.153757  19.335941 -99.257339   -7803.668457  107.926704
# 2       241.942535  19.361479 -99.321487   41655.167969  134.810928
# 3       123.036278  19.439266 -99.194984   45935.535156  395.677094
# 4       187.501724  19.395832 -99.169670   60247.015625  320.607788
#
#   tipo_propiedad              Municipio               Colonia     cp  \
# 0           Casa         Álvaro Obregón    Paseo De Las Lomas   1330
# 1   Departamento         Álvaro Obregón  Olivar De Los Padres   1780
# 2           Casa  Cuajimalpa de Morelos                     0   5200
# 3   Departamento         Miguel Hidalgo               Polanco  11529
# 4   Departamento             Cuauhtémoc     Hipodromo Condesa   6170
#
#   estacionamientos edad recamaras banos
# 0                2    2         3     4
# 1                2   27         2     2
# 2                2    5         3     4
# 3                3   14         2     1
# 4                2   15         3     3
# Epoch 1237/4000 - Loss Total: 2.3225 | Num Loss: 0.2963 | Cat Loss: 0.8115 | KL Loss: 1.2148
# Epoch 1238/4000 - Loss Total: 2.3512 | Num Loss: 0.2953 | Cat Loss: 0.8405 | KL Loss: 1.2154
# Epoch 1239/4000 - Loss Total: 2.3413 | Num Loss: 0.2940 | Cat Loss: 0.8314 | KL Loss: 1.2159
# Epoch 1240/4000 - Loss Total: 2.3256 | Num Loss: 0.2952 | Cat Loss: 0.8164 | KL Loss: 1.2141
# Epoch 1241/4000 - Loss Total: 2.3256 | Num Loss: 0.2948 | Cat Loss: 0.8133 | KL Loss: 1.2174
# Epoch 1242/4000 - Loss Total: 2.3312 | Num Loss: 0.2955 | Cat Loss: 0.8188 | KL Loss: 1.2169
# Epoch 1243/4000 - Loss Total: 2.3172 | Num Loss: 0.2954 | Cat Loss: 0.8054 | KL Loss: 1.2164
# Epoch 1244/4000 - Loss Total: 2.3171 | Num Loss: 0.2947 | Cat Loss: 0.8101 | KL Loss: 1.2122
# Epoch 1245/4000 - Loss Total: 2.3241 | Num Loss: 0.2955 | Cat Loss: 0.8136 | KL Loss: 1.2151
# Epoch 1246/4000 - Loss Total: 2.3204 | Num Loss: 0.2963 | Cat Loss: 0.8094 | KL Loss: 1.2146
# Epoch 1247/4000 - Loss Total: 2.3297 | Num Loss: 0.2956 | Cat Loss: 0.8164 | KL Loss: 1.2176
# Epoch 1248/4000 - Loss Total: 2.3192 | Num Loss: 0.2948 | Cat Loss: 0.8096 | KL Loss: 1.2148
# Epoch 1249/4000 - Loss Total: 2.3200 | Num Loss: 0.2947 | Cat Loss: 0.8108 | KL Loss: 1.2144
# Epoch 1250/4000 - Loss Total: 2.3186 | Num Loss: 0.2949 | Cat Loss: 0.8118 | KL Loss: 1.2119
# Epoch 1251/4000 - Loss Total: 2.3242 | Num Loss: 0.2947 | Cat Loss: 0.8147 | KL Loss: 1.2148
# Epoch 1252/4000 - Loss Total: 2.3188 | Num Loss: 0.2945 | Cat Loss: 0.8067 | KL Loss: 1.2176
# Epoch 1253/4000 - Loss Total: 2.3218 | Num Loss: 0.2950 | Cat Loss: 0.8133 | KL Loss: 1.2135
# Epoch 1254/4000 - Loss Total: 2.3195 | Num Loss: 0.2954 | Cat Loss: 0.8097 | KL Loss: 1.2144
# Epoch 1255/4000 - Loss Total: 2.3194 | Num Loss: 0.2948 | Cat Loss: 0.8091 | KL Loss: 1.2154
# Epoch 1256/4000 - Loss Total: 2.3186 | Num Loss: 0.2952 | Cat Loss: 0.8072 | KL Loss: 1.2162
# Epoch 1257/4000 - Loss Total: 2.3248 | Num Loss: 0.2959 | Cat Loss: 0.8127 | KL Loss: 1.2162
# Epoch 1258/4000 - Loss Total: 2.3209 | Num Loss: 0.2952 | Cat Loss: 0.8120 | KL Loss: 1.2137
# Epoch 1259/4000 - Loss Total: 2.3186 | Num Loss: 0.2941 | Cat Loss: 0.8104 | KL Loss: 1.2142
# Epoch 1260/4000 - Loss Total: 2.3225 | Num Loss: 0.2961 | Cat Loss: 0.8123 | KL Loss: 1.2141
# Epoch 1261/4000 - Loss Total: 2.3160 | Num Loss: 0.2948 | Cat Loss: 0.8067 | KL Loss: 1.2146
# Epoch 1262/4000 - Loss Total: 2.3231 | Num Loss: 0.2947 | Cat Loss: 0.8130 | KL Loss: 1.2154
# Epoch 1263/4000 - Loss Total: 2.3156 | Num Loss: 0.2946 | Cat Loss: 0.8076 | KL Loss: 1.2134
# Epoch 1264/4000 - Loss Total: 2.3276 | Num Loss: 0.2959 | Cat Loss: 0.8173 | KL Loss: 1.2144
# Epoch 1265/4000 - Loss Total: 2.3218 | Num Loss: 0.2956 | Cat Loss: 0.8119 | KL Loss: 1.2144
# Epoch 1266/4000 - Loss Total: 2.3287 | Num Loss: 0.2956 | Cat Loss: 0.8170 | KL Loss: 1.2161
# Epoch 1267/4000 - Loss Total: 2.3234 | Num Loss: 0.2952 | Cat Loss: 0.8133 | KL Loss: 1.2149
# Epoch 1268/4000 - Loss Total: 2.3205 | Num Loss: 0.2960 | Cat Loss: 0.8102 | KL Loss: 1.2144
# Epoch 1269/4000 - Loss Total: 2.3197 | Num Loss: 0.2955 | Cat Loss: 0.8099 | KL Loss: 1.2144
# Epoch 1270/4000 - Loss Total: 2.3184 | Num Loss: 0.2948 | Cat Loss: 0.8069 | KL Loss: 1.2167
# Epoch 1271/4000 - Loss Total: 2.3214 | Num Loss: 0.2954 | Cat Loss: 0.8109 | KL Loss: 1.2151
# Epoch 1272/4000 - Loss Total: 2.3240 | Num Loss: 0.2955 | Cat Loss: 0.8106 | KL Loss: 1.2179
# Epoch 1273/4000 - Loss Total: 2.3248 | Num Loss: 0.2947 | Cat Loss: 0.8133 | KL Loss: 1.2168
# Epoch 1274/4000 - Loss Total: 2.3207 | Num Loss: 0.2952 | Cat Loss: 0.8095 | KL Loss: 1.2160
# Epoch 1275/4000 - Loss Total: 2.3270 | Num Loss: 0.2947 | Cat Loss: 0.8161 | KL Loss: 1.2162
# Epoch 1276/4000 - Loss Total: 2.3177 | Num Loss: 0.2943 | Cat Loss: 0.8096 | KL Loss: 1.2138
# Epoch 1277/4000 - Loss Total: 2.3170 | Num Loss: 0.2953 | Cat Loss: 0.8065 | KL Loss: 1.2152
# Epoch 1278/4000 - Loss Total: 2.3186 | Num Loss: 0.2951 | Cat Loss: 0.8090 | KL Loss: 1.2145
# Epoch 1279/4000 - Loss Total: 2.3225 | Num Loss: 0.2954 | Cat Loss: 0.8132 | KL Loss: 1.2140
# Epoch 1280/4000 - Loss Total: 2.3167 | Num Loss: 0.2953 | Cat Loss: 0.8078 | KL Loss: 1.2136
# Epoch 1281/4000 - Loss Total: 2.3145 | Num Loss: 0.2947 | Cat Loss: 0.8071 | KL Loss: 1.2127
# Epoch 1282/4000 - Loss Total: 2.3217 | Num Loss: 0.2958 | Cat Loss: 0.8127 | KL Loss: 1.2132
# Epoch 1283/4000 - Loss Total: 2.3151 | Num Loss: 0.2943 | Cat Loss: 0.8057 | KL Loss: 1.2151
# Epoch 1284/4000 - Loss Total: 2.3259 | Num Loss: 0.2951 | Cat Loss: 0.8153 | KL Loss: 1.2156
# Epoch 1285/4000 - Loss Total: 2.3197 | Num Loss: 0.2938 | Cat Loss: 0.8122 | KL Loss: 1.2137
# Epoch 1286/4000 - Loss Total: 2.3098 | Num Loss: 0.2951 | Cat Loss: 0.8018 | KL Loss: 1.2129
# Epoch 1287/4000 - Loss Total: 2.3190 | Num Loss: 0.2957 | Cat Loss: 0.8104 | KL Loss: 1.2129
# Epoch 1288/4000 - Loss Total: 2.3215 | Num Loss: 0.2951 | Cat Loss: 0.8111 | KL Loss: 1.2153
# Epoch 1289/4000 - Loss Total: 2.3211 | Num Loss: 0.2937 | Cat Loss: 0.8100 | KL Loss: 1.2174
# Epoch 1290/4000 - Loss Total: 2.3164 | Num Loss: 0.2951 | Cat Loss: 0.8054 | KL Loss: 1.2159
# Epoch 1291/4000 - Loss Total: 2.3158 | Num Loss: 0.2951 | Cat Loss: 0.8050 | KL Loss: 1.2157
# Epoch 1292/4000 - Loss Total: 2.3124 | Num Loss: 0.2955 | Cat Loss: 0.8027 | KL Loss: 1.2141
#
# [Step 2300000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       182.872009  19.417471 -99.179169   47858.773438  429.790527
# 1       215.979568  19.374285 -99.250557   50280.664062  306.604309
# 2       -66.496330  19.259665 -99.107368   -9690.086914   88.103951
# 3       113.800507  19.430845 -99.181274   26657.855469  280.226898
# 4       233.814575  19.340734 -99.206970   55169.894531  229.856735
#
#   tipo_propiedad              Municipio                Colonia     cp  \
# 0   Departamento             Cuauhtémoc      Hipodromo Condesa   6170
# 1   Departamento  Cuajimalpa de Morelos       Gral C A Madrazo   1320
# 2   Departamento               Coyoacán             El Caracol   4700
# 3   Departamento         Miguel Hidalgo       Veronica Anzures  11300
# 4   Departamento         Álvaro Obregón  Jardines Del Pedregal   1900
#
#   estacionamientos edad recamaras banos
# 0                3    2         2     1
# 1                2   40         2     2
# 2                0   34         2     1
# 3                0    0         1     1
# 4                0    0         3     3
# Epoch 1293/4000 - Loss Total: 2.3167 | Num Loss: 0.2964 | Cat Loss: 0.8070 | KL Loss: 1.2133
# Epoch 1294/4000 - Loss Total: 2.3203 | Num Loss: 0.2961 | Cat Loss: 0.8100 | KL Loss: 1.2142
# Epoch 1295/4000 - Loss Total: 2.3176 | Num Loss: 0.2960 | Cat Loss: 0.8064 | KL Loss: 1.2153
# Epoch 1296/4000 - Loss Total: 2.3203 | Num Loss: 0.2959 | Cat Loss: 0.8089 | KL Loss: 1.2155
# Epoch 1297/4000 - Loss Total: 2.3212 | Num Loss: 0.2942 | Cat Loss: 0.8125 | KL Loss: 1.2145
# Epoch 1298/4000 - Loss Total: 2.3172 | Num Loss: 0.2943 | Cat Loss: 0.8082 | KL Loss: 1.2147
# Epoch 1299/4000 - Loss Total: 2.3185 | Num Loss: 0.2951 | Cat Loss: 0.8117 | KL Loss: 1.2116
# Epoch 1300/4000 - Loss Total: 2.3204 | Num Loss: 0.2950 | Cat Loss: 0.8099 | KL Loss: 1.2155
# Epoch 1301/4000 - Loss Total: 2.3171 | Num Loss: 0.2945 | Cat Loss: 0.8063 | KL Loss: 1.2164
# Epoch 1302/4000 - Loss Total: 2.3168 | Num Loss: 0.2945 | Cat Loss: 0.8080 | KL Loss: 1.2143
# Epoch 1303/4000 - Loss Total: 2.3173 | Num Loss: 0.2943 | Cat Loss: 0.8066 | KL Loss: 1.2163
# Epoch 1304/4000 - Loss Total: 2.3069 | Num Loss: 0.2944 | Cat Loss: 0.7981 | KL Loss: 1.2144
# Epoch 1305/4000 - Loss Total: 2.3207 | Num Loss: 0.2954 | Cat Loss: 0.8091 | KL Loss: 1.2162
# Epoch 1306/4000 - Loss Total: 2.3109 | Num Loss: 0.2947 | Cat Loss: 0.8019 | KL Loss: 1.2143
# Epoch 1307/4000 - Loss Total: 2.3094 | Num Loss: 0.2945 | Cat Loss: 0.8027 | KL Loss: 1.2122
# Epoch 1308/4000 - Loss Total: 2.3166 | Num Loss: 0.2950 | Cat Loss: 0.8076 | KL Loss: 1.2140
# Epoch 1309/4000 - Loss Total: 2.3251 | Num Loss: 0.2951 | Cat Loss: 0.8123 | KL Loss: 1.2177
# Epoch 1310/4000 - Loss Total: 2.3069 | Num Loss: 0.2948 | Cat Loss: 0.7971 | KL Loss: 1.2150
# Epoch 1311/4000 - Loss Total: 2.3192 | Num Loss: 0.2953 | Cat Loss: 0.8090 | KL Loss: 1.2150
# Epoch 1312/4000 - Loss Total: 2.3136 | Num Loss: 0.2949 | Cat Loss: 0.8025 | KL Loss: 1.2162
# Epoch 1313/4000 - Loss Total: 2.3168 | Num Loss: 0.2954 | Cat Loss: 0.8042 | KL Loss: 1.2172
# Epoch 1314/4000 - Loss Total: 2.3115 | Num Loss: 0.2948 | Cat Loss: 0.8026 | KL Loss: 1.2141
# Epoch 1315/4000 - Loss Total: 2.3165 | Num Loss: 0.2941 | Cat Loss: 0.8068 | KL Loss: 1.2156
# Epoch 1316/4000 - Loss Total: 2.3081 | Num Loss: 0.2946 | Cat Loss: 0.8006 | KL Loss: 1.2130
# Epoch 1317/4000 - Loss Total: 2.3127 | Num Loss: 0.2954 | Cat Loss: 0.8045 | KL Loss: 1.2128
# Epoch 1318/4000 - Loss Total: 2.3216 | Num Loss: 0.2955 | Cat Loss: 0.8106 | KL Loss: 1.2155
# Epoch 1319/4000 - Loss Total: 2.3122 | Num Loss: 0.2949 | Cat Loss: 0.8006 | KL Loss: 1.2168
# Epoch 1320/4000 - Loss Total: 2.3099 | Num Loss: 0.2947 | Cat Loss: 0.8009 | KL Loss: 1.2143
# Epoch 1321/4000 - Loss Total: 2.3148 | Num Loss: 0.2948 | Cat Loss: 0.8057 | KL Loss: 1.2143
# Epoch 1322/4000 - Loss Total: 2.3230 | Num Loss: 0.2941 | Cat Loss: 0.8134 | KL Loss: 1.2155
# Epoch 1323/4000 - Loss Total: 2.3132 | Num Loss: 0.2956 | Cat Loss: 0.8045 | KL Loss: 1.2131
# Epoch 1324/4000 - Loss Total: 2.3086 | Num Loss: 0.2941 | Cat Loss: 0.7991 | KL Loss: 1.2153
# Epoch 1325/4000 - Loss Total: 2.3127 | Num Loss: 0.2950 | Cat Loss: 0.8043 | KL Loss: 1.2134
# Epoch 1326/4000 - Loss Total: 2.3181 | Num Loss: 0.2947 | Cat Loss: 0.8086 | KL Loss: 1.2148
# Epoch 1327/4000 - Loss Total: 2.3128 | Num Loss: 0.2949 | Cat Loss: 0.8030 | KL Loss: 1.2150
# Epoch 1328/4000 - Loss Total: 2.3178 | Num Loss: 0.2951 | Cat Loss: 0.8057 | KL Loss: 1.2170
# Epoch 1329/4000 - Loss Total: 2.3220 | Num Loss: 0.2968 | Cat Loss: 0.8111 | KL Loss: 1.2141
# Epoch 1330/4000 - Loss Total: 2.3137 | Num Loss: 0.2957 | Cat Loss: 0.8036 | KL Loss: 1.2144
# Epoch 1331/4000 - Loss Total: 2.3049 | Num Loss: 0.2946 | Cat Loss: 0.7946 | KL Loss: 1.2157
# Epoch 1332/4000 - Loss Total: 2.3166 | Num Loss: 0.2955 | Cat Loss: 0.8071 | KL Loss: 1.2140
# Epoch 1333/4000 - Loss Total: 2.3154 | Num Loss: 0.2948 | Cat Loss: 0.8068 | KL Loss: 1.2138
# Epoch 1334/4000 - Loss Total: 2.3116 | Num Loss: 0.2953 | Cat Loss: 0.8014 | KL Loss: 1.2148
# Epoch 1335/4000 - Loss Total: 2.3116 | Num Loss: 0.2947 | Cat Loss: 0.8024 | KL Loss: 1.2145
# Epoch 1336/4000 - Loss Total: 2.3136 | Num Loss: 0.2939 | Cat Loss: 0.8045 | KL Loss: 1.2152
# Epoch 1337/4000 - Loss Total: 2.3146 | Num Loss: 0.2956 | Cat Loss: 0.8035 | KL Loss: 1.2155
# Epoch 1338/4000 - Loss Total: 2.3180 | Num Loss: 0.2943 | Cat Loss: 0.8068 | KL Loss: 1.2170
# Epoch 1339/4000 - Loss Total: 2.3053 | Num Loss: 0.2959 | Cat Loss: 0.7963 | KL Loss: 1.2131
# Epoch 1340/4000 - Loss Total: 2.3116 | Num Loss: 0.2957 | Cat Loss: 0.8005 | KL Loss: 1.2154
# Epoch 1341/4000 - Loss Total: 2.3112 | Num Loss: 0.2950 | Cat Loss: 0.8022 | KL Loss: 1.2139
# Epoch 1342/4000 - Loss Total: 2.3165 | Num Loss: 0.2959 | Cat Loss: 0.8036 | KL Loss: 1.2170
# Epoch 1343/4000 - Loss Total: 2.3081 | Num Loss: 0.2946 | Cat Loss: 0.8001 | KL Loss: 1.2134
# Epoch 1344/4000 - Loss Total: 2.3089 | Num Loss: 0.2953 | Cat Loss: 0.7989 | KL Loss: 1.2148
# Epoch 1345/4000 - Loss Total: 2.3106 | Num Loss: 0.2950 | Cat Loss: 0.7998 | KL Loss: 1.2158
# Epoch 1346/4000 - Loss Total: 2.3097 | Num Loss: 0.2946 | Cat Loss: 0.8003 | KL Loss: 1.2148
# Epoch 1347/4000 - Loss Total: 2.3110 | Num Loss: 0.2953 | Cat Loss: 0.8013 | KL Loss: 1.2143
# Epoch 1348/4000 - Loss Total: 2.3195 | Num Loss: 0.2955 | Cat Loss: 0.8079 | KL Loss: 1.2161
# Epoch 1349/4000 - Loss Total: 2.3093 | Num Loss: 0.2953 | Cat Loss: 0.7987 | KL Loss: 1.2153
#
# [Step 2400000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       233.083054  19.431871 -99.162514   50033.671875  237.874832
# 1       120.388794  19.310358 -99.307556   19260.658203  163.515015
# 2       384.179169  19.438143 -99.179291  124620.390625  338.248840
# 3       332.372559  19.399094 -99.164711  105896.640625  326.455292
# 4       387.224335  19.416214 -99.204895  111163.460938  324.553131
#
#   tipo_propiedad              Municipio       Colonia     cp estacionamientos  \
# 0   Departamento             Cuauhtémoc        Juarez   6600                1
# 1   Departamento  Cuajimalpa de Morelos  La Magdalena   5600                0
# 2           Casa         Miguel Hidalgo       Polanco  11550                4
# 3   Departamento             Cuauhtémoc     Hipodromo   6100                1
# 4           Casa         Miguel Hidalgo       Granada  11520                4
#
#   edad recamaras banos
# 0   49         3     4
# 1   10         2     2
# 2    5         4     3
# 3   52         7     1
# 4    1         4     3
# Epoch 1350/4000 - Loss Total: 2.3075 | Num Loss: 0.2938 | Cat Loss: 0.7987 | KL Loss: 1.2150
# Epoch 1351/4000 - Loss Total: 2.3035 | Num Loss: 0.2941 | Cat Loss: 0.7965 | KL Loss: 1.2129
# Epoch 1352/4000 - Loss Total: 2.3118 | Num Loss: 0.2947 | Cat Loss: 0.8003 | KL Loss: 1.2168
# Epoch 1353/4000 - Loss Total: 2.2984 | Num Loss: 0.2949 | Cat Loss: 0.7909 | KL Loss: 1.2125
# Epoch 1354/4000 - Loss Total: 2.3090 | Num Loss: 0.2936 | Cat Loss: 0.8024 | KL Loss: 1.2131
# Epoch 1355/4000 - Loss Total: 2.3233 | Num Loss: 0.2952 | Cat Loss: 0.8136 | KL Loss: 1.2145
# Epoch 1356/4000 - Loss Total: 2.3113 | Num Loss: 0.2945 | Cat Loss: 0.8045 | KL Loss: 1.2123
# Epoch 1357/4000 - Loss Total: 2.3075 | Num Loss: 0.2956 | Cat Loss: 0.7954 | KL Loss: 1.2165
# Epoch 1358/4000 - Loss Total: 2.3117 | Num Loss: 0.2933 | Cat Loss: 0.8027 | KL Loss: 1.2157
# Epoch 1359/4000 - Loss Total: 2.3050 | Num Loss: 0.2960 | Cat Loss: 0.7947 | KL Loss: 1.2143
# Epoch 1360/4000 - Loss Total: 2.3076 | Num Loss: 0.2947 | Cat Loss: 0.7982 | KL Loss: 1.2147
# Epoch 1361/4000 - Loss Total: 2.3073 | Num Loss: 0.2946 | Cat Loss: 0.7977 | KL Loss: 1.2150
# Epoch 1362/4000 - Loss Total: 2.3056 | Num Loss: 0.2951 | Cat Loss: 0.7955 | KL Loss: 1.2150
# Epoch 1363/4000 - Loss Total: 2.3210 | Num Loss: 0.2959 | Cat Loss: 0.8097 | KL Loss: 1.2155
# Epoch 1364/4000 - Loss Total: 2.3030 | Num Loss: 0.2948 | Cat Loss: 0.7942 | KL Loss: 1.2139
# Epoch 1365/4000 - Loss Total: 2.3132 | Num Loss: 0.2946 | Cat Loss: 0.8038 | KL Loss: 1.2149
# Epoch 1366/4000 - Loss Total: 2.3061 | Num Loss: 0.2940 | Cat Loss: 0.7979 | KL Loss: 1.2142
# Epoch 1367/4000 - Loss Total: 2.3108 | Num Loss: 0.2942 | Cat Loss: 0.8011 | KL Loss: 1.2155
# Epoch 1368/4000 - Loss Total: 2.3082 | Num Loss: 0.2953 | Cat Loss: 0.7989 | KL Loss: 1.2140
# Epoch 1369/4000 - Loss Total: 2.3085 | Num Loss: 0.2945 | Cat Loss: 0.7975 | KL Loss: 1.2165
# Epoch 1370/4000 - Loss Total: 2.3055 | Num Loss: 0.2943 | Cat Loss: 0.7958 | KL Loss: 1.2154
# Epoch 1371/4000 - Loss Total: 2.3182 | Num Loss: 0.2959 | Cat Loss: 0.8062 | KL Loss: 1.2160
# Epoch 1372/4000 - Loss Total: 2.3027 | Num Loss: 0.2938 | Cat Loss: 0.7955 | KL Loss: 1.2135
# Epoch 1373/4000 - Loss Total: 2.3082 | Num Loss: 0.2950 | Cat Loss: 0.8020 | KL Loss: 1.2111
# Epoch 1374/4000 - Loss Total: 2.3068 | Num Loss: 0.2949 | Cat Loss: 0.7962 | KL Loss: 1.2157
# Epoch 1375/4000 - Loss Total: 2.3123 | Num Loss: 0.2960 | Cat Loss: 0.7992 | KL Loss: 1.2171
# Epoch 1376/4000 - Loss Total: 2.3294 | Num Loss: 0.2964 | Cat Loss: 0.8181 | KL Loss: 1.2149
# Epoch 1377/4000 - Loss Total: 2.3042 | Num Loss: 0.2945 | Cat Loss: 0.7949 | KL Loss: 1.2148
# Epoch 1378/4000 - Loss Total: 2.3034 | Num Loss: 0.2951 | Cat Loss: 0.7946 | KL Loss: 1.2138
# Epoch 1379/4000 - Loss Total: 2.3107 | Num Loss: 0.2950 | Cat Loss: 0.8002 | KL Loss: 1.2154
# Epoch 1380/4000 - Loss Total: 2.3084 | Num Loss: 0.2957 | Cat Loss: 0.7977 | KL Loss: 1.2149
# Epoch 1381/4000 - Loss Total: 2.3055 | Num Loss: 0.2943 | Cat Loss: 0.7986 | KL Loss: 1.2126
# Epoch 1382/4000 - Loss Total: 2.3071 | Num Loss: 0.2952 | Cat Loss: 0.7967 | KL Loss: 1.2152
# Epoch 1383/4000 - Loss Total: 2.3060 | Num Loss: 0.2937 | Cat Loss: 0.7970 | KL Loss: 1.2152
# Epoch 1384/4000 - Loss Total: 2.3038 | Num Loss: 0.2948 | Cat Loss: 0.7929 | KL Loss: 1.2160
# Epoch 1385/4000 - Loss Total: 2.3042 | Num Loss: 0.2951 | Cat Loss: 0.7924 | KL Loss: 1.2167
# Epoch 1386/4000 - Loss Total: 2.3063 | Num Loss: 0.2946 | Cat Loss: 0.7960 | KL Loss: 1.2157
# Epoch 1387/4000 - Loss Total: 2.3170 | Num Loss: 0.2943 | Cat Loss: 0.8066 | KL Loss: 1.2162
# Epoch 1388/4000 - Loss Total: 2.3062 | Num Loss: 0.2942 | Cat Loss: 0.7940 | KL Loss: 1.2179
# Epoch 1389/4000 - Loss Total: 2.3095 | Num Loss: 0.2954 | Cat Loss: 0.7984 | KL Loss: 1.2156
# Epoch 1390/4000 - Loss Total: 2.2985 | Num Loss: 0.2941 | Cat Loss: 0.7905 | KL Loss: 1.2139
# Epoch 1391/4000 - Loss Total: 2.3040 | Num Loss: 0.2938 | Cat Loss: 0.7960 | KL Loss: 1.2141
# Epoch 1392/4000 - Loss Total: 2.3013 | Num Loss: 0.2939 | Cat Loss: 0.7935 | KL Loss: 1.2139
# Epoch 1393/4000 - Loss Total: 2.3035 | Num Loss: 0.2943 | Cat Loss: 0.7949 | KL Loss: 1.2143
# Epoch 1394/4000 - Loss Total: 2.3289 | Num Loss: 0.2954 | Cat Loss: 0.8207 | KL Loss: 1.2128
# Epoch 1395/4000 - Loss Total: 2.3047 | Num Loss: 0.2941 | Cat Loss: 0.7961 | KL Loss: 1.2144
# Epoch 1396/4000 - Loss Total: 2.3036 | Num Loss: 0.2948 | Cat Loss: 0.7945 | KL Loss: 1.2143
# Epoch 1397/4000 - Loss Total: 2.3076 | Num Loss: 0.2952 | Cat Loss: 0.7973 | KL Loss: 1.2152
# Epoch 1398/4000 - Loss Total: 2.3029 | Num Loss: 0.2945 | Cat Loss: 0.7927 | KL Loss: 1.2158
# Epoch 1399/4000 - Loss Total: 2.3061 | Num Loss: 0.2946 | Cat Loss: 0.7955 | KL Loss: 1.2160
# Epoch 1400/4000 - Loss Total: 2.3022 | Num Loss: 0.2934 | Cat Loss: 0.7923 | KL Loss: 1.2165
# Epoch 1401/4000 - Loss Total: 2.3043 | Num Loss: 0.2957 | Cat Loss: 0.7920 | KL Loss: 1.2166
# Epoch 1402/4000 - Loss Total: 2.3107 | Num Loss: 0.2988 | Cat Loss: 0.7970 | KL Loss: 1.2150
# Epoch 1403/4000 - Loss Total: 2.2994 | Num Loss: 0.2951 | Cat Loss: 0.7926 | KL Loss: 1.2117
# Epoch 1404/4000 - Loss Total: 2.2963 | Num Loss: 0.2945 | Cat Loss: 0.7880 | KL Loss: 1.2138
# Epoch 1405/4000 - Loss Total: 2.3085 | Num Loss: 0.2954 | Cat Loss: 0.7982 | KL Loss: 1.2149
#
# [Step 2500000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       198.434937  19.387491 -99.173035   73269.492188  419.700317
# 1        87.148636  19.449650 -99.181671   31468.335938  312.249023
# 2        84.870750  19.437698 -99.196999   47037.441406  376.741913
# 3       101.624672  19.371801 -99.257034   36717.804688  316.098480
# 4       214.328201  19.448179 -99.109650   16872.160156  124.553246
#
#   tipo_propiedad              Municipio                 Colonia     cp  \
# 0   Departamento          Benito Juárez                       0   3330
# 1   Departamento         Miguel Hidalgo        Veronica Anzures  11300
# 2   Departamento         Miguel Hidalgo                 Polanco  11550
# 3   Departamento  Cuajimalpa de Morelos                       0   5320
# 4           Casa      Gustavo A. Madero  Acueducto De Guadalupe   7270
#
#   estacionamientos edad recamaras banos
# 0                2    2         2     2
# 1                0    6         2     2
# 2                0    0         2     2
# 3                0    3         2     2
# 4                2    1         3     2
# Epoch 1406/4000 - Loss Total: 2.3017 | Num Loss: 0.2949 | Cat Loss: 0.7935 | KL Loss: 1.2133
# Epoch 1407/4000 - Loss Total: 2.3044 | Num Loss: 0.2947 | Cat Loss: 0.7968 | KL Loss: 1.2129
# Epoch 1408/4000 - Loss Total: 2.2951 | Num Loss: 0.2938 | Cat Loss: 0.7868 | KL Loss: 1.2145
# Epoch 1409/4000 - Loss Total: 2.2958 | Num Loss: 0.2939 | Cat Loss: 0.7891 | KL Loss: 1.2128
# Epoch 1410/4000 - Loss Total: 2.3099 | Num Loss: 0.2947 | Cat Loss: 0.7991 | KL Loss: 1.2162
# Epoch 1411/4000 - Loss Total: 2.3067 | Num Loss: 0.2954 | Cat Loss: 0.7960 | KL Loss: 1.2153
# Epoch 1412/4000 - Loss Total: 2.3039 | Num Loss: 0.2950 | Cat Loss: 0.7941 | KL Loss: 1.2148
# Epoch 1413/4000 - Loss Total: 2.3040 | Num Loss: 0.2944 | Cat Loss: 0.7951 | KL Loss: 1.2146
# Epoch 1414/4000 - Loss Total: 2.3087 | Num Loss: 0.2958 | Cat Loss: 0.7981 | KL Loss: 1.2148
# Epoch 1415/4000 - Loss Total: 2.3036 | Num Loss: 0.2958 | Cat Loss: 0.7918 | KL Loss: 1.2160
# Epoch 1416/4000 - Loss Total: 2.3031 | Num Loss: 0.2953 | Cat Loss: 0.7925 | KL Loss: 1.2153
# Epoch 1417/4000 - Loss Total: 2.3083 | Num Loss: 0.2940 | Cat Loss: 0.8010 | KL Loss: 1.2133
# Epoch 1418/4000 - Loss Total: 2.3028 | Num Loss: 0.2950 | Cat Loss: 0.7927 | KL Loss: 1.2150
# Epoch 1419/4000 - Loss Total: 2.3014 | Num Loss: 0.2945 | Cat Loss: 0.7928 | KL Loss: 1.2141
# Epoch 1420/4000 - Loss Total: 2.3026 | Num Loss: 0.2948 | Cat Loss: 0.7934 | KL Loss: 1.2144
# Epoch 1421/4000 - Loss Total: 2.3022 | Num Loss: 0.2956 | Cat Loss: 0.7927 | KL Loss: 1.2139
# Epoch 1422/4000 - Loss Total: 2.3043 | Num Loss: 0.2950 | Cat Loss: 0.7946 | KL Loss: 1.2147
# Epoch 1423/4000 - Loss Total: 2.2967 | Num Loss: 0.2957 | Cat Loss: 0.7867 | KL Loss: 1.2144
# Epoch 1424/4000 - Loss Total: 2.3085 | Num Loss: 0.2950 | Cat Loss: 0.7985 | KL Loss: 1.2150
# Epoch 1425/4000 - Loss Total: 2.3090 | Num Loss: 0.2950 | Cat Loss: 0.7963 | KL Loss: 1.2177
# Epoch 1426/4000 - Loss Total: 2.2972 | Num Loss: 0.2952 | Cat Loss: 0.7872 | KL Loss: 1.2149
# Epoch 1427/4000 - Loss Total: 2.3105 | Num Loss: 0.2953 | Cat Loss: 0.7994 | KL Loss: 1.2158
# Epoch 1428/4000 - Loss Total: 2.3003 | Num Loss: 0.2946 | Cat Loss: 0.7888 | KL Loss: 1.2168
# Epoch 1429/4000 - Loss Total: 2.3004 | Num Loss: 0.2944 | Cat Loss: 0.7906 | KL Loss: 1.2154
# Epoch 1430/4000 - Loss Total: 2.3017 | Num Loss: 0.2944 | Cat Loss: 0.7905 | KL Loss: 1.2168
# Epoch 1431/4000 - Loss Total: 2.2924 | Num Loss: 0.2953 | Cat Loss: 0.7844 | KL Loss: 1.2127
# Epoch 1432/4000 - Loss Total: 2.3040 | Num Loss: 0.2950 | Cat Loss: 0.7937 | KL Loss: 1.2153
# Epoch 1433/4000 - Loss Total: 2.2942 | Num Loss: 0.2946 | Cat Loss: 0.7856 | KL Loss: 1.2140
# Epoch 1434/4000 - Loss Total: 2.3002 | Num Loss: 0.2948 | Cat Loss: 0.7923 | KL Loss: 1.2130
# Epoch 1435/4000 - Loss Total: 2.3012 | Num Loss: 0.2951 | Cat Loss: 0.7956 | KL Loss: 1.2105
# Epoch 1436/4000 - Loss Total: 2.2952 | Num Loss: 0.2956 | Cat Loss: 0.7871 | KL Loss: 1.2124
# Epoch 1437/4000 - Loss Total: 2.3044 | Num Loss: 0.2943 | Cat Loss: 0.7926 | KL Loss: 1.2174
# ...
# Epoch 3867/4000 - Loss Total: 2.2168 | Num Loss: 0.2961 | Cat Loss: 0.7079 | KL Loss: 1.2127
# Epoch 3868/4000 - Loss Total: 2.2206 | Num Loss: 0.2970 | Cat Loss: 0.7111 | KL Loss: 1.2125
# Epoch 3869/4000 - Loss Total: 2.2289 | Num Loss: 0.2975 | Cat Loss: 0.7188 | KL Loss: 1.2126
# Epoch 3870/4000 - Loss Total: 2.2249 | Num Loss: 0.2964 | Cat Loss: 0.7155 | KL Loss: 1.2130
# Epoch 3871/4000 - Loss Total: 2.2267 | Num Loss: 0.2962 | Cat Loss: 0.7160 | KL Loss: 1.2145
# Epoch 3872/4000 - Loss Total: 2.2153 | Num Loss: 0.2978 | Cat Loss: 0.7036 | KL Loss: 1.2139
# Epoch 3873/4000 - Loss Total: 2.2200 | Num Loss: 0.2963 | Cat Loss: 0.7118 | KL Loss: 1.2119
# Epoch 3874/4000 - Loss Total: 2.2168 | Num Loss: 0.2968 | Cat Loss: 0.7083 | KL Loss: 1.2117
# Epoch 3875/4000 - Loss Total: 2.2263 | Num Loss: 0.2975 | Cat Loss: 0.7170 | KL Loss: 1.2118
# Epoch 3876/4000 - Loss Total: 2.2295 | Num Loss: 0.2967 | Cat Loss: 0.7173 | KL Loss: 1.2155
# Epoch 3877/4000 - Loss Total: 2.2177 | Num Loss: 0.2968 | Cat Loss: 0.7076 | KL Loss: 1.2134
# Epoch 3878/4000 - Loss Total: 2.2170 | Num Loss: 0.2966 | Cat Loss: 0.7081 | KL Loss: 1.2123
#
# [Step 6900000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       160.870636  19.459139 -99.196007   60001.398438  439.859680
# 1       279.390991  19.352308 -99.296402   43643.023438   96.264702
# 2       242.097168  19.399065 -99.156898   68103.101562  314.204102
# 3       257.716400  19.373413 -99.258484   55919.921875  237.958466
# 4       141.083328  19.427536 -99.119125   74284.632812  615.921021
#
#   tipo_propiedad              Municipio            Colonia     cp  \
# 0   Departamento         Miguel Hidalgo  Anahuac Dos Lagos  11290
# 1   Departamento  Cuajimalpa de Morelos      Manzanastitla   5280
# 2   Departamento             Cuauhtémoc  Hipodromo Condesa   6100
# 3   Departamento  Cuajimalpa de Morelos                  0   5348
# 4   Departamento             Cuauhtémoc                  0   6100
#
#   estacionamientos edad recamaras banos
# 0                3    2         2     2
# 1                4    3         3     3
# 2                4    2         3     2
# 3                1    0         3     3
# 4                2    2         1     1
# Epoch 3879/4000 - Loss Total: 2.2311 | Num Loss: 0.2967 | Cat Loss: 0.7194 | KL Loss: 1.2151
# Epoch 3880/4000 - Loss Total: 2.2155 | Num Loss: 0.2974 | Cat Loss: 0.7034 | KL Loss: 1.2147
# Epoch 3881/4000 - Loss Total: 2.2205 | Num Loss: 0.2971 | Cat Loss: 0.7100 | KL Loss: 1.2134
# Epoch 3882/4000 - Loss Total: 2.2218 | Num Loss: 0.2965 | Cat Loss: 0.7127 | KL Loss: 1.2126
# Epoch 3883/4000 - Loss Total: 2.2129 | Num Loss: 0.2958 | Cat Loss: 0.7055 | KL Loss: 1.2116
# Epoch 3884/4000 - Loss Total: 2.2219 | Num Loss: 0.2971 | Cat Loss: 0.7130 | KL Loss: 1.2118
# Epoch 3885/4000 - Loss Total: 2.2188 | Num Loss: 0.2975 | Cat Loss: 0.7074 | KL Loss: 1.2139
# Epoch 3886/4000 - Loss Total: 2.2185 | Num Loss: 0.2968 | Cat Loss: 0.7080 | KL Loss: 1.2137
# Epoch 3887/4000 - Loss Total: 2.2119 | Num Loss: 0.2966 | Cat Loss: 0.7022 | KL Loss: 1.2131
# Epoch 3888/4000 - Loss Total: 2.2182 | Num Loss: 0.2966 | Cat Loss: 0.7082 | KL Loss: 1.2134
# Epoch 3889/4000 - Loss Total: 2.2248 | Num Loss: 0.2967 | Cat Loss: 0.7151 | KL Loss: 1.2130
# Epoch 3890/4000 - Loss Total: 2.2219 | Num Loss: 0.2960 | Cat Loss: 0.7118 | KL Loss: 1.2141
# Epoch 3891/4000 - Loss Total: 2.2118 | Num Loss: 0.2972 | Cat Loss: 0.7025 | KL Loss: 1.2121
# Epoch 3892/4000 - Loss Total: 2.2105 | Num Loss: 0.2965 | Cat Loss: 0.7000 | KL Loss: 1.2140
# Epoch 3893/4000 - Loss Total: 2.2326 | Num Loss: 0.2979 | Cat Loss: 0.7202 | KL Loss: 1.2144
# Epoch 3894/4000 - Loss Total: 2.2243 | Num Loss: 0.2968 | Cat Loss: 0.7120 | KL Loss: 1.2155
# Epoch 3895/4000 - Loss Total: 2.2168 | Num Loss: 0.2958 | Cat Loss: 0.7063 | KL Loss: 1.2147
# Epoch 3896/4000 - Loss Total: 2.2186 | Num Loss: 0.2974 | Cat Loss: 0.7082 | KL Loss: 1.2131
# Epoch 3897/4000 - Loss Total: 2.2213 | Num Loss: 0.2963 | Cat Loss: 0.7111 | KL Loss: 1.2140
# Epoch 3898/4000 - Loss Total: 2.2218 | Num Loss: 0.2969 | Cat Loss: 0.7121 | KL Loss: 1.2129
# Epoch 3899/4000 - Loss Total: 2.2319 | Num Loss: 0.2980 | Cat Loss: 0.7177 | KL Loss: 1.2163
# Epoch 3900/4000 - Loss Total: 2.2143 | Num Loss: 0.2961 | Cat Loss: 0.7067 | KL Loss: 1.2115
# Epoch 3901/4000 - Loss Total: 2.2165 | Num Loss: 0.2973 | Cat Loss: 0.7066 | KL Loss: 1.2127
# Epoch 3902/4000 - Loss Total: 2.2313 | Num Loss: 0.2968 | Cat Loss: 0.7179 | KL Loss: 1.2166
# Epoch 3903/4000 - Loss Total: 2.2247 | Num Loss: 0.2970 | Cat Loss: 0.7127 | KL Loss: 1.2150
# Epoch 3904/4000 - Loss Total: 2.2234 | Num Loss: 0.2964 | Cat Loss: 0.7150 | KL Loss: 1.2120
# Epoch 3905/4000 - Loss Total: 2.2142 | Num Loss: 0.2969 | Cat Loss: 0.7063 | KL Loss: 1.2110
# Epoch 3906/4000 - Loss Total: 2.2277 | Num Loss: 0.2978 | Cat Loss: 0.7168 | KL Loss: 1.2132
# Epoch 3907/4000 - Loss Total: 2.2129 | Num Loss: 0.2968 | Cat Loss: 0.7025 | KL Loss: 1.2136
# Epoch 3908/4000 - Loss Total: 2.2310 | Num Loss: 0.2970 | Cat Loss: 0.7197 | KL Loss: 1.2142
# Epoch 3909/4000 - Loss Total: 2.2167 | Num Loss: 0.2975 | Cat Loss: 0.7090 | KL Loss: 1.2102
# Epoch 3910/4000 - Loss Total: 2.2191 | Num Loss: 0.2974 | Cat Loss: 0.7115 | KL Loss: 1.2102
# Epoch 3911/4000 - Loss Total: 2.2178 | Num Loss: 0.2967 | Cat Loss: 0.7071 | KL Loss: 1.2140
# Epoch 3912/4000 - Loss Total: 2.2222 | Num Loss: 0.2961 | Cat Loss: 0.7111 | KL Loss: 1.2149
# Epoch 3913/4000 - Loss Total: 2.2189 | Num Loss: 0.2966 | Cat Loss: 0.7072 | KL Loss: 1.2151
# Epoch 3914/4000 - Loss Total: 2.2196 | Num Loss: 0.2962 | Cat Loss: 0.7093 | KL Loss: 1.2141
# Epoch 3915/4000 - Loss Total: 2.2148 | Num Loss: 0.2964 | Cat Loss: 0.7041 | KL Loss: 1.2143
# Epoch 3916/4000 - Loss Total: 2.2202 | Num Loss: 0.2961 | Cat Loss: 0.7106 | KL Loss: 1.2135
# Epoch 3917/4000 - Loss Total: 2.2198 | Num Loss: 0.2974 | Cat Loss: 0.7102 | KL Loss: 1.2123
# Epoch 3918/4000 - Loss Total: 2.2389 | Num Loss: 0.2973 | Cat Loss: 0.7268 | KL Loss: 1.2148
# Epoch 3919/4000 - Loss Total: 2.2167 | Num Loss: 0.2963 | Cat Loss: 0.7067 | KL Loss: 1.2138
# Epoch 3920/4000 - Loss Total: 2.2245 | Num Loss: 0.2963 | Cat Loss: 0.7137 | KL Loss: 1.2145
# Epoch 3921/4000 - Loss Total: 2.2206 | Num Loss: 0.2975 | Cat Loss: 0.7102 | KL Loss: 1.2130
# Epoch 3922/4000 - Loss Total: 2.2159 | Num Loss: 0.2980 | Cat Loss: 0.7050 | KL Loss: 1.2129
# Epoch 3923/4000 - Loss Total: 2.2273 | Num Loss: 0.2974 | Cat Loss: 0.7167 | KL Loss: 1.2132
# Epoch 3924/4000 - Loss Total: 2.2133 | Num Loss: 0.2971 | Cat Loss: 0.7047 | KL Loss: 1.2115
# Epoch 3925/4000 - Loss Total: 2.2244 | Num Loss: 0.2971 | Cat Loss: 0.7135 | KL Loss: 1.2139
# Epoch 3926/4000 - Loss Total: 2.2210 | Num Loss: 0.2971 | Cat Loss: 0.7118 | KL Loss: 1.2121
# Epoch 3927/4000 - Loss Total: 2.2294 | Num Loss: 0.2961 | Cat Loss: 0.7201 | KL Loss: 1.2132
# Epoch 3928/4000 - Loss Total: 2.2152 | Num Loss: 0.2964 | Cat Loss: 0.7070 | KL Loss: 1.2118
# Epoch 3929/4000 - Loss Total: 2.2159 | Num Loss: 0.2963 | Cat Loss: 0.7072 | KL Loss: 1.2124
# Epoch 3930/4000 - Loss Total: 2.2109 | Num Loss: 0.2961 | Cat Loss: 0.7017 | KL Loss: 1.2130
# Epoch 3931/4000 - Loss Total: 2.2247 | Num Loss: 0.2972 | Cat Loss: 0.7154 | KL Loss: 1.2121
# Epoch 3932/4000 - Loss Total: 2.2195 | Num Loss: 0.2967 | Cat Loss: 0.7103 | KL Loss: 1.2126
# Epoch 3933/4000 - Loss Total: 2.2259 | Num Loss: 0.2965 | Cat Loss: 0.7164 | KL Loss: 1.2130
# Epoch 3934/4000 - Loss Total: 2.2301 | Num Loss: 0.2972 | Cat Loss: 0.7165 | KL Loss: 1.2164
#
# [Step 7000000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       165.145676  19.374775 -99.159698   25756.968750  122.632225
# 1       146.752396  19.397495 -99.169548   52073.011719  379.365509
# 2        45.720409  19.387711 -99.161461    9379.909180  148.110275
# 3        80.895599  19.361692 -99.270241   26980.591797  258.133698
# 4       138.219894  19.400091 -99.151985   26961.792969  187.954941
#
#   tipo_propiedad              Municipio               Colonia     cp  \
# 0           Casa          Benito Juárez               Acacias   3240
# 1   Departamento         Miguel Hidalgo               Granada  11520
# 2   Departamento    Venustiano Carranza  San Diego Churubusco   4120
# 3   Departamento  Cuajimalpa de Morelos              El Yaqui   5240
# 4           Casa          Benito Juárez                Postal   3410
#
#   estacionamientos edad recamaras banos
# 0                0    3         3     2
# 1                2   12         2     1
# 2                1   70         2     1
# 3                0    5         2     2
# 4                3    0         3     2
# Epoch 3935/4000 - Loss Total: 2.2251 | Num Loss: 0.2960 | Cat Loss: 0.7147 | KL Loss: 1.2144
# Epoch 3936/4000 - Loss Total: 2.2144 | Num Loss: 0.2961 | Cat Loss: 0.7058 | KL Loss: 1.2124
# Epoch 3937/4000 - Loss Total: 2.2220 | Num Loss: 0.2959 | Cat Loss: 0.7135 | KL Loss: 1.2127
# Epoch 3938/4000 - Loss Total: 2.2348 | Num Loss: 0.2977 | Cat Loss: 0.7219 | KL Loss: 1.2153
# Epoch 3939/4000 - Loss Total: 2.2193 | Num Loss: 0.2969 | Cat Loss: 0.7079 | KL Loss: 1.2145
# Epoch 3940/4000 - Loss Total: 2.2199 | Num Loss: 0.2963 | Cat Loss: 0.7090 | KL Loss: 1.2146
# Epoch 3941/4000 - Loss Total: 2.2204 | Num Loss: 0.2967 | Cat Loss: 0.7096 | KL Loss: 1.2141
# Epoch 3942/4000 - Loss Total: 2.2099 | Num Loss: 0.2961 | Cat Loss: 0.7016 | KL Loss: 1.2122
# Epoch 3943/4000 - Loss Total: 2.2243 | Num Loss: 0.2976 | Cat Loss: 0.7145 | KL Loss: 1.2121
# Epoch 3944/4000 - Loss Total: 2.2229 | Num Loss: 0.2969 | Cat Loss: 0.7121 | KL Loss: 1.2139
# Epoch 3945/4000 - Loss Total: 2.2246 | Num Loss: 0.2957 | Cat Loss: 0.7144 | KL Loss: 1.2144
# Epoch 3946/4000 - Loss Total: 2.2258 | Num Loss: 0.2973 | Cat Loss: 0.7146 | KL Loss: 1.2139
# Epoch 3947/4000 - Loss Total: 2.2190 | Num Loss: 0.2963 | Cat Loss: 0.7088 | KL Loss: 1.2139
# Epoch 3948/4000 - Loss Total: 2.2144 | Num Loss: 0.2971 | Cat Loss: 0.7059 | KL Loss: 1.2114
# Epoch 3949/4000 - Loss Total: 2.2279 | Num Loss: 0.2964 | Cat Loss: 0.7160 | KL Loss: 1.2155
# Epoch 3950/4000 - Loss Total: 2.2235 | Num Loss: 0.2978 | Cat Loss: 0.7119 | KL Loss: 1.2139
# Epoch 3951/4000 - Loss Total: 2.2231 | Num Loss: 0.2968 | Cat Loss: 0.7131 | KL Loss: 1.2133
# Epoch 3952/4000 - Loss Total: 2.2119 | Num Loss: 0.2969 | Cat Loss: 0.7009 | KL Loss: 1.2142
# Epoch 3953/4000 - Loss Total: 2.2110 | Num Loss: 0.2960 | Cat Loss: 0.7024 | KL Loss: 1.2127
# Epoch 3954/4000 - Loss Total: 2.2211 | Num Loss: 0.2966 | Cat Loss: 0.7087 | KL Loss: 1.2158
# Epoch 3955/4000 - Loss Total: 2.2186 | Num Loss: 0.2967 | Cat Loss: 0.7064 | KL Loss: 1.2156
# Epoch 3956/4000 - Loss Total: 2.2207 | Num Loss: 0.2961 | Cat Loss: 0.7095 | KL Loss: 1.2150
# Epoch 3957/4000 - Loss Total: 2.2129 | Num Loss: 0.2961 | Cat Loss: 0.7046 | KL Loss: 1.2122
# Epoch 3958/4000 - Loss Total: 2.2183 | Num Loss: 0.2962 | Cat Loss: 0.7091 | KL Loss: 1.2130
# Epoch 3959/4000 - Loss Total: 2.2239 | Num Loss: 0.2964 | Cat Loss: 0.7123 | KL Loss: 1.2153
# Epoch 3960/4000 - Loss Total: 2.2262 | Num Loss: 0.2981 | Cat Loss: 0.7115 | KL Loss: 1.2166
# Epoch 3961/4000 - Loss Total: 2.2151 | Num Loss: 0.2969 | Cat Loss: 0.7045 | KL Loss: 1.2137
# Epoch 3962/4000 - Loss Total: 2.2141 | Num Loss: 0.2977 | Cat Loss: 0.7025 | KL Loss: 1.2140
# Epoch 3963/4000 - Loss Total: 2.2158 | Num Loss: 0.2976 | Cat Loss: 0.7050 | KL Loss: 1.2132
# Epoch 3964/4000 - Loss Total: 2.2211 | Num Loss: 0.2960 | Cat Loss: 0.7099 | KL Loss: 1.2152
# Epoch 3965/4000 - Loss Total: 2.2323 | Num Loss: 0.2974 | Cat Loss: 0.7184 | KL Loss: 1.2166
# Epoch 3966/4000 - Loss Total: 2.2315 | Num Loss: 0.2973 | Cat Loss: 0.7184 | KL Loss: 1.2158
# Epoch 3967/4000 - Loss Total: 2.2190 | Num Loss: 0.2972 | Cat Loss: 0.7077 | KL Loss: 1.2140
# Epoch 3968/4000 - Loss Total: 2.2324 | Num Loss: 0.2973 | Cat Loss: 0.7182 | KL Loss: 1.2168
# Epoch 3969/4000 - Loss Total: 2.2240 | Num Loss: 0.2972 | Cat Loss: 0.7099 | KL Loss: 1.2169
# Epoch 3970/4000 - Loss Total: 2.2235 | Num Loss: 0.2971 | Cat Loss: 0.7114 | KL Loss: 1.2149
# Epoch 3971/4000 - Loss Total: 2.2203 | Num Loss: 0.2965 | Cat Loss: 0.7104 | KL Loss: 1.2134
# Epoch 3972/4000 - Loss Total: 2.2280 | Num Loss: 0.2993 | Cat Loss: 0.7129 | KL Loss: 1.2158
# Epoch 3973/4000 - Loss Total: 2.2222 | Num Loss: 0.2968 | Cat Loss: 0.7105 | KL Loss: 1.2149
# Epoch 3974/4000 - Loss Total: 2.2164 | Num Loss: 0.2977 | Cat Loss: 0.7026 | KL Loss: 1.2160
# Epoch 3975/4000 - Loss Total: 2.2316 | Num Loss: 0.2973 | Cat Loss: 0.7184 | KL Loss: 1.2159
# Epoch 3976/4000 - Loss Total: 2.2226 | Num Loss: 0.2976 | Cat Loss: 0.7107 | KL Loss: 1.2143
# Epoch 3977/4000 - Loss Total: 2.2151 | Num Loss: 0.2975 | Cat Loss: 0.7032 | KL Loss: 1.2144
# Epoch 3978/4000 - Loss Total: 2.2190 | Num Loss: 0.2962 | Cat Loss: 0.7097 | KL Loss: 1.2131
# Epoch 3979/4000 - Loss Total: 2.2213 | Num Loss: 0.2964 | Cat Loss: 0.7133 | KL Loss: 1.2116
# Epoch 3980/4000 - Loss Total: 2.2174 | Num Loss: 0.2965 | Cat Loss: 0.7067 | KL Loss: 1.2142
# Epoch 3981/4000 - Loss Total: 2.2182 | Num Loss: 0.2974 | Cat Loss: 0.7082 | KL Loss: 1.2126
# Epoch 3982/4000 - Loss Total: 2.2235 | Num Loss: 0.2975 | Cat Loss: 0.7121 | KL Loss: 1.2140
# Epoch 3983/4000 - Loss Total: 2.2188 | Num Loss: 0.2961 | Cat Loss: 0.7070 | KL Loss: 1.2157
# Epoch 3984/4000 - Loss Total: 2.2193 | Num Loss: 0.2966 | Cat Loss: 0.7084 | KL Loss: 1.2143
# Epoch 3985/4000 - Loss Total: 2.2285 | Num Loss: 0.2961 | Cat Loss: 0.7195 | KL Loss: 1.2130
# Epoch 3986/4000 - Loss Total: 2.2178 | Num Loss: 0.2960 | Cat Loss: 0.7088 | KL Loss: 1.2131
# Epoch 3987/4000 - Loss Total: 2.2173 | Num Loss: 0.2966 | Cat Loss: 0.7075 | KL Loss: 1.2133
# Epoch 3988/4000 - Loss Total: 2.2230 | Num Loss: 0.2970 | Cat Loss: 0.7140 | KL Loss: 1.2120
# Epoch 3989/4000 - Loss Total: 2.2227 | Num Loss: 0.2967 | Cat Loss: 0.7115 | KL Loss: 1.2146
# Epoch 3990/4000 - Loss Total: 2.2183 | Num Loss: 0.2964 | Cat Loss: 0.7087 | KL Loss: 1.2132
# Epoch 3991/4000 - Loss Total: 2.2174 | Num Loss: 0.2971 | Cat Loss: 0.7047 | KL Loss: 1.2155
#
# [Step 7100000] Ejemplo de datos sintéticos:
#    area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 0       300.878357  19.375776 -99.162926   45854.613281  206.079941
# 1       440.079895  19.375000 -99.221054  103084.492188  282.294983
# 2       293.948242  19.346767 -99.264137   54339.320312  216.463593
# 3       208.892670  19.435783 -99.175858   65709.664062  320.867767
# 4       412.536102  19.337690 -99.212753   93827.070312  320.884979
#
#   tipo_propiedad              Municipio                 Colonia     cp  \
# 0           Casa          Benito Juárez  San Pedro De Los Pinos   3820
# 1   Departamento          Benito Juárez     Insurgentes Mixcoac   3900
# 2           Casa  Cuajimalpa de Morelos              Zentlapatl   5010
# 3   Departamento         Miguel Hidalgo                 Polanco  11560
# 4   Departamento          Benito Juárez                       0   3920
#
#   estacionamientos edad recamaras banos
# 0                2    0         4     5
# 1                0    3         4     4
# 2                3    6         3     2
# 3                1    2         2     2
# 4                0   49         4     4
# Epoch 3992/4000 - Loss Total: 2.2123 | Num Loss: 0.2959 | Cat Loss: 0.7041 | KL Loss: 1.2123
# Epoch 3993/4000 - Loss Total: 2.2155 | Num Loss: 0.2961 | Cat Loss: 0.7040 | KL Loss: 1.2154
# Epoch 3994/4000 - Loss Total: 2.2195 | Num Loss: 0.2967 | Cat Loss: 0.7091 | KL Loss: 1.2138
# Epoch 3995/4000 - Loss Total: 2.2279 | Num Loss: 0.2965 | Cat Loss: 0.7175 | KL Loss: 1.2140
# Epoch 3996/4000 - Loss Total: 2.2262 | Num Loss: 0.2969 | Cat Loss: 0.7157 | KL Loss: 1.2136
# Epoch 3997/4000 - Loss Total: 2.2229 | Num Loss: 0.2953 | Cat Loss: 0.7138 | KL Loss: 1.2138
# Epoch 3998/4000 - Loss Total: 2.2168 | Num Loss: 0.2960 | Cat Loss: 0.7061 | KL Loss: 1.2147
# Epoch 3999/4000 - Loss Total: 2.2238 | Num Loss: 0.2982 | Cat Loss: 0.7128 | KL Loss: 1.2128
# Epoch 4000/4000 - Loss Total: 2.2253 | Num Loss: 0.2967 | Cat Loss: 0.7119 | KL Loss: 1.2166

# %% [markdown]
# ´´´
# Cardinalidades de variables categóricas: {'tipo_propiedad': 2, 'Municipio': 16, 'Colonia': 1222, 'cp': 950, 'estacionamientos': 11, 'edad': 91, 'recamaras': 11, 'banos': 11}
# ´´´

# %%
ls
# Out:
# TABTRASNFORMER.ipynb  final.csv
# checkpoint.pt         training_log.csv

# %%
df_logs = pd.read_csv("training_log.csv")
df_logs
# Out:
#                 timestamp  epoch  loss_total  loss_num   loss_cat   loss_kl
# 0     2025-02-12 20:07:41      1   13.752757  0.528518  12.353585  0.870654
# 1     2025-02-12 20:07:57      2    9.026920  0.368844   7.435230  1.222845
# 2     2025-02-12 20:08:15      3    7.614089  0.342485   6.040275  1.231329
# 3     2025-02-12 20:08:31      4    6.883336  0.328362   5.354229  1.200744
# 4     2025-02-12 20:08:47      5    6.391731  0.319630   4.899327  1.172774
# ...                   ...    ...         ...       ...        ...       ...
# 3995  2025-02-15 21:26:47   3996    2.226216  0.296925   0.715683  1.213607
# 3996  2025-02-15 21:27:00   3997    2.222917  0.295338   0.713767  1.213812
# 3997  2025-02-15 21:27:14   3998    2.216800  0.296027   0.706090  1.214684
# 3998  2025-02-15 21:27:28   3999    2.223825  0.298238   0.712806  1.212781
# 3999  2025-02-15 21:27:41   4000    2.225306  0.296740   0.711919  1.216647
#
# [4000 rows x 6 columns]

# %%
synthetic_batch_size = 1000
z = torch.randn(synthetic_batch_size, latent_dim)
num_syn, cat_syn_logits = model.decode(z)
num_syn_np = num_syn.detach().numpy()

synthetic_nums = []
for i, col in enumerate(numerical_cols):
    col_vals = num_syn_np[:, i].reshape(-1, 1)
    col_inv = scalers[col].inverse_transform(col_vals).flatten()
    synthetic_nums.append(col_inv)
synthetic_nums = np.column_stack(synthetic_nums)

synthetic_cat = []
for i, logits in enumerate(cat_syn_logits):
    preds = torch.argmax(logits, dim=1).cpu().numpy()
    preds = [reverse_cat_mapping[categorical_cols[i]][p] for p in preds]
    synthetic_cat.append(preds)
synthetic_cat = np.column_stack(synthetic_cat)

synthetic_df = pd.DataFrame(synthetic_nums, columns=numerical_cols)
for i, col in enumerate(categorical_cols):
    synthetic_df[col] = synthetic_cat[:, i]

# %%
synthetic_df.sample(10)
# Out:
#      area_construida    latitud   longitud  precio_oferta   precio_m2  \
# 89        122.932220  19.402515 -99.118858   31938.810547  233.268021
# 460       140.375351  19.418264 -99.171364   49725.554688  400.253784
# 332       250.379456  19.278044 -99.199303   47966.164062  174.779678
# 711       115.771980  19.406483 -99.238022   15408.752930  219.717819
# 654       376.189514  19.383360 -99.272118   77635.726562  139.009659
# 602       171.814972  19.400476 -99.222054   53252.656250  330.976501
# 529        89.544350  19.406815 -99.166405   38707.500000  411.714905
# 416        93.184845  19.410168 -99.143784   19218.285156  248.515671
# 351       151.541534  19.406456 -99.119949   23518.144531  131.646393
# 699       141.554428  19.368010 -99.269600   35870.292969  259.426575
#
#     tipo_propiedad              Municipio                          Colonia  \
# 89    Departamento             Cuauhtémoc                       Tabacalera
# 460   Departamento             Cuauhtémoc                          Condesa
# 332   Departamento               Coyoacán  Jardines Del Pedregal San Angel
# 711   Departamento  Cuajimalpa de Morelos           Lomas De Vista Hermosa
# 654           Casa  Cuajimalpa de Morelos                    Royal Reforma
# 602   Departamento         Miguel Hidalgo             Lomas De Chapultepec
# 529   Departamento             Cuauhtémoc                        Hipodromo
# 416   Departamento          Benito Juárez                           Alamos
# 351   Departamento             Cuauhtémoc                           Obrera
# 699   Departamento  Cuajimalpa de Morelos              Santa Fe Cuajimalpa
#
#         cp estacionamientos edad recamaras banos
# 89   13010                2    5         3     1
# 460   6140                3    9         2     2
# 332   4500                2   17         3     2
# 711   5120                0    0         2     1
# 654   5120                0   18         3     4
# 602  11000                4    0         1     1
# 529   6100                2    6         2     1
# 416   3400                2   18         2     2
# 351   8500                0    0         3     2
# 699   5120                0    0         3     2

# %%
x = df_logs[["epoch", "loss_total"]]["epoch"]
y = df_logs[["epoch", "loss_total"]]["loss_total"]


import matplotlib.pyplot as plt

plt.plot(x, y)
plt.show()
